# %% [markdown]
# # Text Mining 20th Century Events

# %% [markdown]
# ## Contents
#     Tokenization
#     Stop Words and Punctuation
#     Additional Stop Words
#     POS Tags with TextBlob
#     Nouns
#     Verbs
#     Adjectives
#     Counting Country Occurrences
#     Sentiment Analysis

# %%
# Import libraries
from textblob import TextBlob 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jboer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jboer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jboer\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Tokenization

# %%
# Loading 20th Century text data
myfile = open('20th_Century_Wiki_refined.txt', encoding='latin')

# %%
# Import txt file

with open('20th_Century_Wiki_refined.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %%
# Sentence tokenization 
from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ['The 20th century changed the world in unprecedented ways.', 'The World Wars sparked tension between countries and led to the creation of atomic bombs, the Cold War led to the Space Race and the creation of space-based rockets, and the World Wide Web was created.', "These advancements have played a significant role in citizens' lives and shaped the 21st century into what it is today.Historic events in the 20th century[edit]World at the beginning of the century[edit]Main article: Edwardian eraThe new beginning of the 20th century marked significant changes.", 'The 1900s saw the decade herald a series of inventions, including the automobile, airplane and radio broadcasting.', '1914 saw the completion of the Panama Canal.From 1914 to 1918, the First World War, and its aftermath, caused major changes in the power balance of the world, destroying or transforming some of the most powerful empires.', '"The war to end all wars": World War I (1914â€“1918)[edit]Main article: World War IArrest of a suspect in Sarajevo following the Assassination of Archduke Franz FerdinandThe First World War (or simply WWI), termed "The Great War" by contemporaries, started in July 1914 and ended in November 1918.', "The war was precipitated by the Assassination in Sarajevo of the Austro-Hungarian Empire's heir to the throne, Erzherzog Franz Ferdinand, by Gavrilo Princip, a member of the Young Bosnia liberation movement.", 'After a period of diplomatic and military escalation known as the July Crisis, by the end of July 1914 two coalitions were at war: the Allies, comprised initially of the British Empire, France, and the Russian Empire; and the Central Powers, comprised initially of the German Empire and Austria-Hungary.', '[1][2]In 1917, Russia ended hostile actions against the Central Powers after the fall of the Tsar.', 'The Bolsheviks negotiated the Treaty of Brest-Litovsk with Germany, although it was a huge cost to Russia.', 'In the treaty, Bolshevik Russia ceded the Baltic states to Germany, and its province of Kars Oblast in the South Caucasus to the Ottoman Empire.', 'It also recognized the independence of Ukraine.', '[3] Although Germany shifted huge forces from the eastern to the western front after signing the treaty, it was unable to stop the Allied advance, especially with the entrance of American troops in 1918.', '[4]The war itself was also a chance for the combatant nations to show off their military strength and technological ingenuity.', 'The Germans introduced the machine gun,[5] U-boats[6] and deadly gases.', '[7] The British first used the tank.', '[8] Both sides had a chance to test out their new aircraft to see if they could be used in warfare.', 'It was widely believed that the war would be short.', 'Unfortunately, since trench warfare was the best form of defense, advances on both sides were very slow and came at a terrible cost to lives.', '[9]Division of Austria-Hungary after World War IWhen the war was finally over in 1918, the results would set the stage for the next twenty years.', 'First and foremost, the Germans were forced to sign the Treaty of Versailles, forcing them to make exorbitant payments to repair damages caused during the War.', 'Many Germans felt these reparations were unfair because they did not actually "lose" the war nor did they feel they caused the war (see Stab-in-the-back legend).', '[10] Germany was never occupied by Allied troops, yet it had to accept a liberal democratic government imposed on it by the victors after the abdication of Kaiser Wilhelm.', '[11]Much of the map of Europe was redrawn by the victors based upon the theory that future wars could be prevented if all ethnic groups had their own "homeland".', 'New states like Yugoslavia and Czechoslovakia were created out of the former Austro-Hungarian Empire to accommodate the nationalist aspirations of these groups.', '[12]  An international body called the League of Nations was formed to mediate disputes and prevent future wars, although its ...

# %%
# Word tokenization
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['The', '20th', 'century', 'changed', 'the', 'world', 'in', 'unprecedented', 'ways', '.', 'The', 'World', 'Wars', 'sparked', 'tension', 'between', 'countries', 'and', 'led', 'to', 'the', 'creation', 'of', 'atomic', 'bombs', ',', 'the', 'Cold', 'War', 'led', 'to', 'the', 'Space', 'Race', 'and', 'the', 'creation', 'of', 'space-based', 'rockets', ',', 'and', 'the', 'World', 'Wide', 'Web', 'was', 'created', '.', 'These', 'advancements', 'have', 'played', 'a', 'significant', 'role', 'in', 'citizens', "'", 'lives', 'and', 'shaped', 'the', '21st', 'century', 'into', 'what', 'it', 'is', 'today.Historic', 'events', 'in', 'the', '20th', 'century', '[', 'edit', ']', 'World', 'at', 'the', 'beginning', 'of', 'the', 'century', '[', 'edit', ']', 'Main', 'article', ':', 'Edwardian', 'eraThe', 'new', 'beginning', 'of', 'the', '20th', 'century', 'marked', 'significant', 'changes', '.', 'The', '1900s', 'saw', 'the', 'decade', 'herald', 'a', 'series', 'of', 'inventions', ',', 'including', 'the', 'automobile', ',', 'airplane', 'and', 'radio', 'broadcasting', '.', '1914', 'saw', 'the', 'completion', 'of', 'the', 'Panama', 'Canal.From', '1914', 'to', '1918', ',', 'the', 'First', 'World', 'War', ',', 'and', 'its', 'aftermath', ',', 'caused', 'major', 'changes', 'in', 'the', 'power', 'balance', 'of', 'the', 'world', ',', 'destroying', 'or', 'transforming', 'some', 'of', 'the', 'most', 'powerful', 'empires', '.', '``', 'The', 'war', 'to', 'end', 'all', 'wars', "''", ':', 'World', 'War', 'I', '(', '1914â€', '“', '1918', ')', '[', 'edit', ']', 'Main', 'article', ':', 'World', 'War', 'IArrest', 'of', 'a', 'suspect', 'in', 'Sarajevo', 'following', 'the', 'Assassination', 'of', 'Archduke', 'Franz', 'FerdinandThe', 'First', 'World', 'War', '(', 'or', 'simply', 'WWI', ')', ',', 'termed', '``', 'The', 'Great', 'War', "''", 'by', 'contemporaries', ',', 'started', 'in', 'July', '1914', 'and', 'ended', 'in', 'November', '1918', '.', 'The', 'war', 'was', 'precipitated', 'by', 'the', 'Assassination', 'in', 'Sarajevo', 'of', 'the', 'Austro-Hungarian', 'Empire', "'s", 'heir', 'to', 'the', 'throne', ',', 'Erzherzog', 'Franz', 'Ferdinand', ',', 'by', 'Gavrilo', 'Princip', ',', 'a', 'member', 'of', 'the', 'Young', 'Bosnia', 'liberation', 'movement', '.', 'After', 'a', 'period', 'of', 'diplomatic', 'and', 'military', 'escalation', 'known', 'as', 'the', 'July', 'Crisis', ',', 'by', 'the', 'end', 'of', 'July', '1914', 'two', 'coalitions', 'were', 'at', 'war', ':', 'the', 'Allies', ',', 'comprised', 'initially', 'of', 'the', 'British', 'Empire', ',', 'France', ',', 'and', 'the', 'Russian', 'Empire', ';', 'and', 'the', 'Central', 'Powers', ',', 'comprised', 'initially', 'of', 'the', 'German', 'Empire', 'and', 'Austria-Hungary', '.', '[', '1', ']', '[', '2', ']', 'In', '1917', ',', 'Russia', 'ended', 'hostile', 'actions', 'against', 'the', 'Central', 'Powers', 'after', 'the', 'fall', 'of', 'the', 'Tsar', '.', 'The', 'Bolsheviks', 'negotiated', 'the', 'Treaty', 'of', 'Brest-Litovsk', 'with', 'Germany', ',', 'although', 'it', 'was', 'a', 'huge', 'cost', 'to', 'Russia', '.', 'In', 'the', 'treaty', ',', 'Bolshevik', 'Russia', 'ceded', 'the', 'Baltic', 'states', 'to', 'Germany', ',', 'and', 'its', 'province', 'of', 'Kars', 'Oblast', 'in', 'the', 'South', 'Caucasus', 'to', 'the', 'Ottoman', 'Empire', '.', 'It', 'also', 'recognized', 'the', 'independence', 'of', 'Ukraine', '.', '[', '3', ']', 'Although', 'Germany', 'shifted', 'huge', 'forces', 'from', 'the', 'eastern', 'to', 'the', 'western', 'front', 'after', 'signing', 'the', 'treaty', ',', 'it', 'was', 'unable', 'to', 'stop', 'the', 'Allied', 'advance', ',', 'especially', 'with', 'the', 'entrance', 'of', 'American', 'troops', 'in', '1918', '.', '[', '4', ']', 'The', 'war', 'itself', 'was', 'also', 'a', 'chance', 'for', 'the', 'combatant', 'nations', 'to', 'show', 'off', 'their', 'military', 'strength', 'and', 'technological', 'ingenuity', '.', 'The', 'Germans', 'introduced', 'the', 'machine', 'gun', ',', '[', '5', ']', 'U-boats', ...

# %%
# Create frequency distribution
from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 3272 samples and 13003 outcomes>

# %%
# Check top 10 most common words
top10 = dist_words.most_common(10)
print(top10)
# Out:
# [('the', 934), (',', 715), ('of', 443), ('.', 418), ('and', 335), ('[', 295), (']', 295), ('to', 292), ('in', 241), ('a', 170)]

# %%
# Create a dataframe from top 10 list
df_top10 = pd.DataFrame(top10, columns=['Word', 'Frequency'])
print(df_top10)
# Out:
#   Word  Frequency
# 0  the        934
# 1    ,        715
# 2   of        443
# 3    .        418
# 4  and        335
# 5    [        295
# 6    ]        295
# 7   to        292
# 8   in        241
# 9    a        170

# %%
# Create a bar chart of 10 most common words
plt.figure(figsize=(10, 6))
df_top10.plot(kind='bar', x='Word', y='Frequency', legend=False, color='blue')
plt.title('Top 10 Most Common Words')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Stop Words and Punctuation

# %%
# Defining stopwords
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'once', 'hasn', 'off', 'any', "she's", 're', 'having', 'shan', 'itself', 'should', 'theirs', "aren't", 'while', 'nor', 'themselves', 'don', 'haven', 'am', 'my', 'against', 'doing', 'mightn', 'down', 'was', 'been', 'needn', 'ours', "i'll", 'few', 'their', 'weren', 'before', 'most', "doesn't", 'them', "hasn't", 'own', 'ourselves', 'ain', 'why', 'after', 'just', 'both', 'isn', "we'll", 'through', 'won', 'me', 'can', 'further', 'such', "he'll", 'did', 'each', 'his', 'y', 'be', 'does', 'at', "we've", 'aren', 'the', 'no', 'other', 'it', 'about', 'your', 'whom', 'up', 'these', 'you', 'd', "needn't", "they'd", "we're", 'ma', 'in', 'have', 'with', 'herself', "i'd", 'myself', 'very', 'hadn', 'himself', "it'll", 'some', "couldn't", "i'm", 'o', "mustn't", 'and', 's', 'm', 'same', "he'd", "didn't", 'again', 'so', 'is', 'between', 'has', 'out', 'under', 'who', 'yourself', "isn't", 'below', 'they', 'to', "you're", "weren't", 'i', "you've", 'her', 'a', 'during', 'for', "he's", 'into', 'on', 'she', "i've", 'how', "wouldn't", 'its', 'had', 'yourselves', 'were', "you'll", "it'd", "we'd", "they're", 'll', 'only', 'than', 'as', "you'd", "mightn't", 'too', 'those', 'which', 'couldn', "she'll", 'there', 'until', "should've", "she'd", 'wasn', 'if', 'over', 'didn', "won't", 'now', 'more', 'from', 'not', 'this', 'but', 'an', "that'll", 'that', 'above', "don't", 't', 'we', 'shouldn', 'are', "hadn't", 'then', 'mustn', "shouldn't", 'what', 'yours', "haven't", 'when', 'will', "shan't", 'because', 'being', 'or', 'wouldn', 'him', 'of', "it's", 'where', 'doesn', 'all', 'here', 'hers', 'by', 've', 'our', 'he', 'do', "they've", "they'll", "wasn't"}

# %%
# Removing stopwords in words
filtered_words = [] # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
# Check filtered_words
filtered_words
# Out:
# ['The',
#  '20th',
#  'century',
#  'changed',
#  'world',
#  'unprecedented',
#  'ways',
#  '.',
#  'The',
#  'World',
#  'Wars',
#  'sparked',
#  'tension',
#  'countries',
#  'led',
#  'creation',
#  'atomic',
#  'bombs',
#  ',',
#  'Cold',
#  'War',
#  'led',
#  'Space',
#  'Race',
#  'creation',
#  'space-based',
#  'rockets',
#  ',',
#  'World',
#  'Wide',
#  'Web',
#  'created',
#  '.',
#  'These',
#  'advancements',
#  'played',
#  'significant',
#  'role',
#  'citizens',
#  "'",
#  'lives',
#  'shaped',
#  '21st',
#  'century',
#  'today.Historic',
#  'events',
#  '20th',
#  'century',
#  '[',
#  'edit',
#  ']',
#  'World',
#  'beginning',
#  'century',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'Edwardian',
#  'eraThe',
#  'new',
#  'beginning',
#  '20th',
#  'century',
#  'marked',
#  'significant',
#  'changes',
#  '.',
#  'The',
#  '1900s',
#  'saw',
#  'decade',
#  'herald',
#  'series',
#  'inventions',
#  ',',
#  'including',
#  'automobile',
#  ',',
#  'airplane',
#  'radio',
#  'broadcasting',
#  '.',
#  '1914',
#  'saw',
#  'completion',
#  'Panama',
#  'Canal.From',
#  '1914',
#  '1918',
#  ',',
#  'First',
#  'World',
#  'War',
#  ',',
#  'aftermath',
#  ',',
#  'caused',
#  'major',
#  'changes',
#  'power',
#  'balance',
#  'world',
#  ',',
#  'destroying',
#  'transforming',
#  'powerful',
#  'empires',
#  '.',
#  '``',
#  'The',
#  'war',
#  'end',
#  'wars',
#  "''",
#  ':',
#  'World',
#  'War',
#  'I',
#  '(',
#  '1914â€',
#  '“',
#  '1918',
#  ')',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'World',
#  'War',
#  'IArrest',
#  'suspect',
#  'Sarajevo',
#  'following',
#  'Assassination',
#  'Archduke',
#  'Franz',
#  'FerdinandThe',
#  'First',
#  'World',
#  'War',
#  '(',
#  'simply',
#  'WWI',
#  ')',
#  ',',
#  'termed',
#  '``',
#  'The',
#  'Great',
#  'War',
#  "''",
#  'contemporaries',
#  ',',
#  'started',
#  'July',
#  '1914',
#  'ended',
#  'November',
#  '1918',
#  '.',
#  'The',
#  'war',
#  'precipitated',
#  'Assassination',
#  'Sarajevo',
#  'Austro-Hungarian',
#  'Empire',
#  "'s",
#  'heir',
#  'throne',
#  ',',
#  'Erzherzog',
#  'Franz',
#  'Ferdinand',
#  ',',
#  'Gavrilo',
#  'Princip',
#  ',',
#  'member',
#  'Young',
#  'Bosnia',
#  'liberation',
#  'movement',
#  '.',
#  'After',
#  'period',
#  'diplomatic',
#  'military',
#  'escalation',
#  'known',
#  'July',
#  'Crisis',
#  ',',
#  'end',
#  'July',
#  '1914',
#  'two',
#  'coalitions',
#  'war',
#  ':',
#  'Allies',
#  ',',
#  'comprised',
#  'initially',
#  'British',
#  'Empire',
#  ',',
#  'France',
#  ',',
#  'Russian',
#  'Empire',
#  ';',
#  'Central',
#  'Powers',
#  ',',
#  'comprised',
#  'initially',
#  'German',
#  'Empire',
#  'Austria-Hungary',
#  '.',
#  '[',
#  '1',
#  ']',
#  '[',
#  '2',
#  ']',
#  'In',
#  '1917',
#  ',',
#  'Russia',
#  'ended',
#  'hostile',
#  'actions',
#  'Central',
#  'Powers',
#  'fall',
#  'Tsar',
#  '.',
#  'The',
#  'Bolsheviks',
#  'negotiated',
#  'Treaty',
#  'Brest-Litovsk',
#  'Germany',
#  ',',
#  'although',
#  'huge',
#  'cost',
#  'Russia',
#  '.',
#  'In',
#  'treaty',
#  ',',
#  'Bolshevik',
#  'Russia',
#  'ceded',
#  'Baltic',
#  'states',
#  'Germany',
#  ',',
#  'province',
#  'Kars',
#  'Oblast',
#  'South',
#  'Caucasus',
#  'Ottoman',
#  'Empire',
#  '.',
#  'It',
#  'also',
#  'recognized',
#  'independence',
#  'Ukraine',
#  '.',
#  '[',
#  '3',
#  ']',
#  'Although',
#  'Germany',
#  'shifted',
#  'huge',
#  'forces',
#  'eastern',
#  'western',
#  'front',
#  'signing',
#  'treaty',
#  ',',
#  'unable',
#  'stop',
#  'Allied',
#  'advance',
#  ',',
#  'especially',
#  'entrance',
#  'American',
#  'troops',
#  '1918',
#  '.',
#  '[',
#  '4',
#  ']',
#  'The',
#  'war',
#  'also',
#  'chance',
#  'combatant',
#  'nations',
#  'show',
#  'military',
#  'strength',
#  'technological',
#  'ingenuity',
#  '.',
#  'The',
#  'Germans',
#  'introduced',
#  'machine',
#  'gun',
#  ',',
#  '[',
#  '5',
#  ']',
#  'U-boats',
#  '[',
#  '6',
#  ']',
#  'deadly',
#  'gases',
#  '.',
#  '[',
#  '7',
#  ']',
#  'The',
#  'British',
#  'first',
#  'used',
#  'tank',
#  '.',
#  '[',
#  '8',
#  ']',
#  'Both',
#  'sides',
#  'chance',
#  'test',
#  'new',
#  'aircraft',
#  'see',
#  'could',
#  'used',
#  'warfare',
#  '.',
#  'It',
#  'widely',
#  'believed',
#  'war',
#  'would',
#  'short',
#  '.',
#  'Unfortunately',
#  ',',
#  'since',
#  'trench',
#  'warfare',
#  'best',
#  'form',
#  'defense',
#  ',',
#  'advances',
#  'sides',
#  'slow',
#  'came',
#  'terrible',
#  'cost',
#  'lives',
#  '.',
#  '[',
#  '9',
#  ']',
#  'Division',
#  'Austria-Hungary',
#  'World',
#  'War',
#  'IWhen',
#  'war',
#  'finally',
#  '1918',
#  ',',
#  'results',
#  'would',
#  'set',
#  'stage',
#  'next',
#  'twenty',
#  'years',
#  '.',
#  'First',
#  'foremost',
#  ',',
#  'Germans',
#  'forced',
#  'sign',
#  'Treaty',
#  'Versailles',
#  ',',
#  'forcing',
#  'make',
#  'exorbitant',
#  'payments',
#  'repair',
#  'damages',
#  'caused',
#  'War',
#  '.',
#  'Many',
#  'Germans',
#  'felt',
#  'reparations',
#  'unfair',
#  'actually',
#  '``',
#  'lose',
#  "''",
#  'war',
#  'feel',
#  'caused',
#  'war',
#  '(',
#  'see',
#  'Stab-in-the-back',
#  'legend',
#  ')',
#  '.',
#  '[',
#  '10',
#  ']',
#  'Germany',
#  'never',
#  'occupied',
#  'Allied',
#  'troops',
#  ',',
#  'yet',
#  'accept',
#  'liberal',
#  'democratic',
#  'government',
#  'imposed',
#  'victors',
#  'abdication',
#  'Kaiser',
#  'Wilhelm',
#  '.',
#  '[',
#  '11',
#  ']',
#  'Much',
#  'map',
#  'Europe',
#  'redrawn',
#  'victors',
#  'based',
#  'upon',
#  'theory',
#  'future',
#  'wars',
#  'could',
#  'prevented',
#  'ethnic',
#  'groups',
#  '``',
#  'homeland',
#  "''",
#  '.',
#  'New',
#  'states',
#  'like',
#  'Yugoslavia',
#  'Czechoslovakia',
#  'created',
#  'former',
#  'Austro-Hungarian',
#  'Empire',
#  'accommodate',
#  'nationalist',
#  'aspirations',
#  'groups',
#  '.',
#  '[',
#  '12',
#  ']',
#  'An',
#  'international',
#  'body',
#  'called',
#  'League',
#  'Nations',
#  'formed',
#  'mediate',
#  'disputes',
#  'prevent',
#  'future',
#  'wars',
#  ',',
#  'although',
#  'effectiveness',
#  'severely',
#  'limited',
#  ',',
#  'among',
#  'things',
#  ',',
#  'reluctance',
#  'inability',
#  'act',
#  '.',
#  '[',
#  '13',
#  ']',
#  'Russian',
#  'Revolution',
#  'communism',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'article',
#  ':',
#  'Russian',
#  'RevolutionThe',
#  'Russian',
#  'Revolution',
#  '1917',
#  '(',
#  'ending',
#  'overthrow',
#  'Tsarist',
#  'regime',
#  'execution',
#  'His',
#  'Imperial',
#  'Majesty',
#  'Nicholas',
#  'II',
#  'family',
#  ')',
#  'sparked',
#  'wave',
#  'communist',
#  'revolutions',
#  'across',
#  'Europe',
#  ',',
#  'prompting',
#  'many',
#  'believe',
#  'socialist',
#  'world',
#  'revolution',
#  'could',
#  'realized',
#  'near',
#  'future',
#  '.',
#  '[',
#  '14',
#  ']',
#  'However',
#  ',',
#  'European',
#  'revolutions',
#  'defeated',
#  ',',
#  'Vladimir',
#  'Lenin',
#  'died',
#  '1924',
#  ',',
#  'within',
#  'years',
#  ',',
#  'Joseph',
#  'Stalin',
#  'displaced',
#  'Leon',
#  'Trotsky',
#  'de',
#  'facto',
#  'leader',
#  'Soviet',
#  'Union',
#  '.',
#  'The',
#  'idea',
#  'worldwide',
#  'revolution',
#  'longer',
#  'forefront',
#  ',',
#  'Stalin',
#  'concentrated',
#  '``',
#  'socialism',
#  'one',
#  'country',
#  "''",
#  '[',
#  '15',
#  ']',
#  'embarked',
#  'bold',
#  'plan',
#  'collectivization',
#  'industrialization',
#  '.',
#  '[',
#  '16',
#  ']',
#  'The',
#  'majority',
#  'socialists',
#  'even',
#  'many',
#  'communists',
#  'became',
#  'disillusioned',
#  'Stalin',
#  "'s",
#  'autocratic',
#  'rule',
#  ',',
#  'purges',
#  'assassination',
#  '``',
#  'enemies',
#  "''",
#  ',',
#  'well',
#  'news',
#  'famines',
#  'imposed',
#  'people',
#  '.',
#  '[',
#  '17',
#  ']',
#  'Communism',
#  'strengthened',
#  'force',
#  'Western',
#  'democracies',
#  'global',
#  'economy',
#  'crashed',
#  '1929',
#  'became',
#  'known',
#  'Great',
#  'Depression',
#  '.',
#  'Many',
#  'people',
#  'saw',
#  'first',
#  'stage',
#  'end',
#  'capitalist',
#  'system',
#  'attracted',
#  'Communism',
#  'solution',
#  'economic',
#  'crisis',
#  ',',
#  'especially',
#  'Soviet',
#  'Union',
#  "'s",
#  'economic',
#  'development',
#  '1930s',
#  'strong',
#  ',',
#  'unaffected',
#  'capitalist',
#  'world',
#  "'s",
#  'crisis',
#  '.',
#  '[',
#  '18',
#  ']',
#  'Between',
#  'wars',
#  '[',
#  'edit',
#  ']',
#  'Dorothea',
#  'Lange',
#  "'s",
#  '1936',
#  'photo',
#  'Migrant',
#  'Mother',
#  'one',
#  'iconic',
#  'photos',
#  'associated',
#  'Great',
#  'DepressionMain',
#  'article',
#  ':',
#  'Interwar',
#  'periodEconomic',
#  'depression',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'articles',
#  ':',
#  'Roaring',
#  'Twenties',
#  'Great',
#  'DepressionAfter',
#  'World',
#  'War',
#  'I',
#  ',',
#  'global',
#  'economy',
#  'remained',
#  'strong',
#  '1920s',
#  '.',
#  'The',
#  'war',
#  'provided',
#  'stimulus',
#  'industry',
#  'economic',
#  'activity',
#  'general',
#  '.',
#  'There',
#  'many',
#  'warning',
#  'signs',
#  'foretelling',
#  'crash',
#  '29',
#  'global',
#  'economic',
#  'system',
#  'end',
#  'decade',
#  ',',
#  'generally',
#  'understood',
#  'political',
#  'leadership',
#  'time',
#  '.',
#  '[',
#  '19',
#  ']',
#  'The',
#  'responses',
#  'crisis',
#  'often',
#  'made',
#  'situation',
#  'worse',
#  ',',
#  'millions',
#  'people',
#  'watched',
#  'savings',
#  'become',
#  'next',
#  'worthless',
#  ',',
#  'idea',
#  'steady',
#  'job',
#  'reasonable',
#  'income',
#  'fading',
#  'away',
#  '.',
#  '[',
#  '20',
#  ']',
#  'Many',
#  'sought',
#  'answers',
#  'alternative',
#  'ideologies',
#  'communism',
#  'fascism',
#  '.',
#  '[',
#  '21',
#  ']',
#  'They',
#  'believed',
#  'capitalist',
#  'economic',
#  'system',
#  'collapsing',
#  'new',
#  'ideas',
#  'required',
#  'meet',
#  'crisis',
#  '.',
#  'The',
#  'early',
#  'responses',
#  'crisis',
#  'based',
#  'assumption',
#  'free',
#  'market',
#  'would',
#  'correct',
#  '.',
#  'This',
#  ',',
#  'however',
#  ',',
#  'little',
#  'correct',
#  'crisis',
#  'alleviate',
#  'suffering',
#  'many',
#  'ordinary',
#  'people',
#  '.',
#  'Thus',
#  ',',
#  'idea',
#  'existing',
#  'system',
#  'could',
#  'reformed',
#  'government',
#  'intervention',
#  'economy',
#  ',',
#  'rather',
#  'continuing',
#  'laissez-faire',
#  'approach',
#  ',',
#  'became',
#  'prominent',
#  'solution',
#  'crisis',
#  '.',
#  'Democratic',
#  'governments',
#  'assumed',
#  'responsibility',
#  'provide',
#  'needed',
#  'services',
#  'society',
#  ',',
#  'alleviate',
#  'poverty',
#  ',',
#  'soon',
#  'gave',
#  'birth',
#  'welfare',
#  'state',
#  '.',
#  '[',
#  '22',
#  ']',
#  'These',
#  'two',
#  'politico-economic',
#  'principles',
#  ',',
#  'belief',
#  'government',
#  'intervention',
#  'welfare',
#  'state',
#  ',',
#  'opposed',
#  'belief',
#  'free',
#  'market',
#  'private',
#  'institutions',
#  ',',
#  'would',
#  'define',
#  'many',
#  'political',
#  'battles',
#  'rest',
#  'century.The',
#  'rise',
#  'dictatorship',
#  '[',
#  'edit',
#  ']',
#  'Main',
#  'articles',
#  ':',
#  'Fascism',
#  ',',
#  'Totalitarianism',
#  ',',
#  'DictatorshipNazi',
#  'soldiers',
#  'hang',
#  'poster',
#  'window',
#  'Jewish-owned',
#  'business',
#  ',',
#  'says',
#  ':',
#  '``',
#  'Germans',
#  ',',
#  'defend',
#  '.',
#  'Do',
#  'buy',
#  'Jews',
#  "''",
#  '.',
#  'Germany',
#  ',',
#  '1933Fascism',
#  'first',
#  'appeared',
#  'Italy',
#  'rise',
#  'power',
#  'Benito',
#  'Mussolini',
#  '1922',
#  '.',
#  '[',
#  '23',
#  ']',
#  'The',
#  'ideology',
#  'supported',
#  'large',
#  'proportion',
#  'upper',
#  'classes',
#  'strong',
#  'challenge',
#  'threat',
#  'communism',
#  '.',
#  '[',
#  '24',
#  ']',
#  'When',
#  'Adolf',
#  'Hitler',
#  'came',
#  'power',
#  'Germany',
#  '1933',
#  ',',
#  'new',
#  'variant',
#  'fascism',
#  'called',
#  'Nazism',
#  'took',
#  'Germany',
#  'ended',
#  'German',
#  'experiment',
#  'democracy',
#  '.',
#  'The',
#  'Nazi',
#  'Party',
#  'Germany',
#  ...]

# %%
# Substitute all punctuation marks with a space 
sans_punc = re.sub("[^a-zA-Z0-9]",  # Search for all non-letters and non-digits
                          " ",          # Replace all non-letters and non-digits with spaces
                          str(filtered_words))

# %% [markdown]
# #### Since the wiki page I scraped deals with events in the 20th century, I thought it would be important to also keeps digits from being replaced. There could be important dates or events with numbers in their name that we may need to analyze.

# %%
# Check list without stop words and punctuation
sans_punc
# Out:
# '  The    20th    century    changed    world    unprecedented    ways         The    World    Wars    sparked    tension    countries    led    creation    atomic    bombs         Cold    War    led    Space    Race    creation    space based    rockets         World    Wide    Web    created         These    advancements    played    significant    role    citizens         lives    shaped    21st    century    today Historic    events    20th    century         edit         World    beginning    century         edit         Main    article         Edwardian    eraThe    new    beginning    20th    century    marked    significant    changes         The    1900s    saw    decade    herald    series    inventions         including    automobile         airplane    radio    broadcasting         1914    saw    completion    Panama    Canal From    1914    1918         First    World    War         aftermath         caused    major    changes    power    balance    world         destroying    transforming    powerful    empires               The    war    end    wars               World    War    I         1914           1918              edit         Main    article         World    War    IArrest    suspect    Sarajevo    following    Assassination    Archduke    Franz    FerdinandThe    First    World    War         simply    WWI              termed          The    Great    War          contemporaries         started    July    1914    ended    November    1918         The    war    precipitated    Assassination    Sarajevo    Austro Hungarian    Empire     s    heir    throne         Erzherzog    Franz    Ferdinand         Gavrilo    Princip         member    Young    Bosnia    liberation    movement         After    period    diplomatic    military    escalation    known    July    Crisis         end    July    1914    two    coalitions    war         Allies         comprised    initially    British    Empire         France         Russian    Empire         Central    Powers         comprised    initially    German    Empire    Austria Hungary              1              2         In    1917         Russia    ended    hostile    actions    Central    Powers    fall    Tsar         The    Bolsheviks    negotiated    Treaty    Brest Litovsk    Germany         although    huge    cost    Russia         In    treaty         Bolshevik    Russia    ceded    Baltic    states    Germany         province    Kars    Oblast    South    Caucasus    Ottoman    Empire         It    also    recognized    independence    Ukraine              3         Although    Germany    shifted    huge    forces    eastern    western    front    signing    treaty         unable    stop    Allied    advance         especially    entrance    American    troops    1918              4         The    war    also    chance    combatant    nations    show    military    strength    technological    ingenuity         The    Germans    introduced    machine    gun              5         U boats         6         deadly    gases              7         The    British    first    used    tank              8         Both    sides    chance    test    new    aircraft    see    could    used    warfare         It    widely    believed    war    would    short         Unfortunately         since    trench    warfare    best    form    defense         advances    sides    slow    came    terrible    cost    lives              9         Division    Austria Hungary    World    War    IWhen    war    finally    1918         results    would    set    stage    next    twenty    years         First    foremost         Germans    forced    sign    Treaty    Versailles         forcing    make    exorbitant    payments    repair    damages    caused    War         Many    Germans    felt    reparations    unfair    actually          lose          war    feel    caused    war         see    Stab in the back    legend                   10         Germany    never    occupied    A ...

# %%
# Re-tokenize our new list by words
tokenized_word_2 = word_tokenize(sans_punc)
print(tokenized_word_2)
# Out:
# ['The', '20th', 'century', 'changed', 'world', 'unprecedented', 'ways', 'The', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', '21st', 'century', 'today', 'Historic', 'events', '20th', 'century', 'edit', 'World', 'beginning', 'century', 'edit', 'Main', 'article', 'Edwardian', 'eraThe', 'new', 'beginning', '20th', 'century', 'marked', 'significant', 'changes', 'The', '1900s', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', '1914', 'saw', 'completion', 'Panama', 'Canal', 'From', '1914', '1918', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'The', 'war', 'end', 'wars', 'World', 'War', 'I', '1914', '1918', 'edit', 'Main', 'article', 'World', 'War', 'IArrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'FerdinandThe', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'The', 'Great', 'War', 'contemporaries', 'started', 'July', '1914', 'ended', 'November', '1918', 'The', 'war', 'precipitated', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 's', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'member', 'Young', 'Bosnia', 'liberation', 'movement', 'After', 'period', 'diplomatic', 'military', 'escalation', 'known', 'July', 'Crisis', 'end', 'July', '1914', 'two', 'coalitions', 'war', 'Allies', 'comprised', 'initially', 'British', 'Empire', 'France', 'Russian', 'Empire', 'Central', 'Powers', 'comprised', 'initially', 'German', 'Empire', 'Austria', 'Hungary', '1', '2', 'In', '1917', 'Russia', 'ended', 'hostile', 'actions', 'Central', 'Powers', 'fall', 'Tsar', 'The', 'Bolsheviks', 'negotiated', 'Treaty', 'Brest', 'Litovsk', 'Germany', 'although', 'huge', 'cost', 'Russia', 'In', 'treaty', 'Bolshevik', 'Russia', 'ceded', 'Baltic', 'states', 'Germany', 'province', 'Kars', 'Oblast', 'South', 'Caucasus', 'Ottoman', 'Empire', 'It', 'also', 'recognized', 'independence', 'Ukraine', '3', 'Although', 'Germany', 'shifted', 'huge', 'forces', 'eastern', 'western', 'front', 'signing', 'treaty', 'unable', 'stop', 'Allied', 'advance', 'especially', 'entrance', 'American', 'troops', '1918', '4', 'The', 'war', 'also', 'chance', 'combatant', 'nations', 'show', 'military', 'strength', 'technological', 'ingenuity', 'The', 'Germans', 'introduced', 'machine', 'gun', '5', 'U', 'boats', '6', 'deadly', 'gases', '7', 'The', 'British', 'first', 'used', 'tank', '8', 'Both', 'sides', 'chance', 'test', 'new', 'aircraft', 'see', 'could', 'used', 'warfare', 'It', 'widely', 'believed', 'war', 'would', 'short', 'Unfortunately', 'since', 'trench', 'warfare', 'best', 'form', 'defense', 'advances', 'sides', 'slow', 'came', 'terrible', 'cost', 'lives', '9', 'Division', 'Austria', 'Hungary', 'World', 'War', 'IWhen', 'war', 'finally', '1918', 'results', 'would', 'set', 'stage', 'next', 'twenty', 'years', 'First', 'foremost', 'Germans', 'forced', 'sign', 'Treaty', 'Versailles', 'forcing', 'make', 'exorbitant', 'payments', 'repair', 'damages', 'caused', 'War', 'Many', 'Germans', 'felt', 'reparations', 'unfair', 'actually', 'lose', 'war', 'feel', 'caused', 'war', 'see', 'Stab', 'in', 'the', 'back', 'legend', '10', 'Germany', 'never', 'occupied', 'Allied', 'troops', 'yet', 'accept', 'liberal', 'democratic', 'government', 'imposed', 'victors', 'abdication', 'Kaiser', 'Wilhelm', '11', 'Much', 'map', 'Europe', 'redrawn', 'victors', 'based', 'upon', 'theory', 'future', 'wars', 'could', 'prevented', 'ethnic', 'groups', 'homeland', 'New', 'states', 'like', 'Yugoslavia', 'Czechoslovakia', 'created', 'former', 'Austro', 'Hungarian', 'Empire', 'accommodate', 'nationalist', 'aspirations', 'groups', '12', 'An', ' ...

# %%
# Create a new FreqDist
dist_words_filter = FreqDist(tokenized_word_2)
print(dist_words_filter)
# Out:
# <FreqDist with 3118 samples and 7210 outcomes>

# %%
# Check top 10 most common words in new list
top10_filter = dist_words_filter.most_common(10)
print(top10_filter)
# Out:
# [('The', 127), ('war', 79), ('War', 55), ('Soviet', 49), ('s', 47), ('Hitler', 39), ('first', 36), ('would', 35), ('World', 33), ('world', 32)]

# %%
# Create a dataframe from new top 10 list
df_top10_filter = pd.DataFrame(top10_filter, columns=['Word', 'Frequency'])
print(df_top10_filter)
# Out:
#      Word  Frequency
# 0     The        127
# 1     war         79
# 2     War         55
# 3  Soviet         49
# 4       s         47
# 5  Hitler         39
# 6   first         36
# 7   would         35
# 8   World         33
# 9   world         32

# %%
# Create a bar chart of 10 most common words
plt.figure(figsize=(10, 6))
df_top10_filter.plot(kind='bar', x='Word', y='Frequency', legend=False, color='blue')
plt.title('Top 10 Most Common Words')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Additional Stop Words

# %%
# Removing additional stop words
new_stopwords = ['The', 's', 'In', 'I', 'It', 'And', 'edit', 'would']

filtered_words_2 = []
for word in tokenized_word_2:
    if word not in new_stopwords:
        filtered_words_2.append(word)
print(filtered_words_2)
# Out:
# ['20th', 'century', 'changed', 'world', 'unprecedented', 'ways', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', '21st', 'century', 'today', 'Historic', 'events', '20th', 'century', 'World', 'beginning', 'century', 'Main', 'article', 'Edwardian', 'eraThe', 'new', 'beginning', '20th', 'century', 'marked', 'significant', 'changes', '1900s', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', '1914', 'saw', 'completion', 'Panama', 'Canal', 'From', '1914', '1918', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'war', 'end', 'wars', 'World', 'War', '1914', '1918', 'Main', 'article', 'World', 'War', 'IArrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'FerdinandThe', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'Great', 'War', 'contemporaries', 'started', 'July', '1914', 'ended', 'November', '1918', 'war', 'precipitated', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'member', 'Young', 'Bosnia', 'liberation', 'movement', 'After', 'period', 'diplomatic', 'military', 'escalation', 'known', 'July', 'Crisis', 'end', 'July', '1914', 'two', 'coalitions', 'war', 'Allies', 'comprised', 'initially', 'British', 'Empire', 'France', 'Russian', 'Empire', 'Central', 'Powers', 'comprised', 'initially', 'German', 'Empire', 'Austria', 'Hungary', '1', '2', '1917', 'Russia', 'ended', 'hostile', 'actions', 'Central', 'Powers', 'fall', 'Tsar', 'Bolsheviks', 'negotiated', 'Treaty', 'Brest', 'Litovsk', 'Germany', 'although', 'huge', 'cost', 'Russia', 'treaty', 'Bolshevik', 'Russia', 'ceded', 'Baltic', 'states', 'Germany', 'province', 'Kars', 'Oblast', 'South', 'Caucasus', 'Ottoman', 'Empire', 'also', 'recognized', 'independence', 'Ukraine', '3', 'Although', 'Germany', 'shifted', 'huge', 'forces', 'eastern', 'western', 'front', 'signing', 'treaty', 'unable', 'stop', 'Allied', 'advance', 'especially', 'entrance', 'American', 'troops', '1918', '4', 'war', 'also', 'chance', 'combatant', 'nations', 'show', 'military', 'strength', 'technological', 'ingenuity', 'Germans', 'introduced', 'machine', 'gun', '5', 'U', 'boats', '6', 'deadly', 'gases', '7', 'British', 'first', 'used', 'tank', '8', 'Both', 'sides', 'chance', 'test', 'new', 'aircraft', 'see', 'could', 'used', 'warfare', 'widely', 'believed', 'war', 'short', 'Unfortunately', 'since', 'trench', 'warfare', 'best', 'form', 'defense', 'advances', 'sides', 'slow', 'came', 'terrible', 'cost', 'lives', '9', 'Division', 'Austria', 'Hungary', 'World', 'War', 'IWhen', 'war', 'finally', '1918', 'results', 'set', 'stage', 'next', 'twenty', 'years', 'First', 'foremost', 'Germans', 'forced', 'sign', 'Treaty', 'Versailles', 'forcing', 'make', 'exorbitant', 'payments', 'repair', 'damages', 'caused', 'War', 'Many', 'Germans', 'felt', 'reparations', 'unfair', 'actually', 'lose', 'war', 'feel', 'caused', 'war', 'see', 'Stab', 'in', 'the', 'back', 'legend', '10', 'Germany', 'never', 'occupied', 'Allied', 'troops', 'yet', 'accept', 'liberal', 'democratic', 'government', 'imposed', 'victors', 'abdication', 'Kaiser', 'Wilhelm', '11', 'Much', 'map', 'Europe', 'redrawn', 'victors', 'based', 'upon', 'theory', 'future', 'wars', 'could', 'prevented', 'ethnic', 'groups', 'homeland', 'New', 'states', 'like', 'Yugoslavia', 'Czechoslovakia', 'created', 'former', 'Austro', 'Hungarian', 'Empire', 'accommodate', 'nationalist', 'aspirations', 'groups', '12', 'An', 'international', 'body', 'called', 'League', 'Nations', 'formed', 'mediate', 'disputes', 'prevent', 'future', 'wars', 'although', 'effectiveness',  ...

# %%
# Converting text to string
text = ' '.join(filtered_words_2)

# %%
# Removing extra numbers in text
cleaned_text = re.sub(r'\b\d{1,2,3}\b', '', text)
print(cleaned_text)
# Out:
# 20th century changed world unprecedented ways World Wars sparked tension countries led creation atomic bombs Cold War led Space Race creation space based rockets World Wide Web created These advancements played significant role citizens lives shaped 21st century today Historic events 20th century World beginning century Main article Edwardian eraThe new beginning 20th century marked significant changes 1900s saw decade herald series inventions including automobile airplane radio broadcasting 1914 saw completion Panama Canal From 1914 1918 First World War aftermath caused major changes power balance world destroying transforming powerful empires war end wars World War 1914 1918 Main article World War IArrest suspect Sarajevo following Assassination Archduke Franz FerdinandThe First World War simply WWI termed Great War contemporaries started July 1914 ended November 1918 war precipitated Assassination Sarajevo Austro Hungarian Empire heir throne Erzherzog Franz Ferdinand Gavrilo Princip member Young Bosnia liberation movement After period diplomatic military escalation known July Crisis end July 1914 two coalitions war Allies comprised initially British Empire France Russian Empire Central Powers comprised initially German Empire Austria Hungary 1 2 1917 Russia ended hostile actions Central Powers fall Tsar Bolsheviks negotiated Treaty Brest Litovsk Germany although huge cost Russia treaty Bolshevik Russia ceded Baltic states Germany province Kars Oblast South Caucasus Ottoman Empire also recognized independence Ukraine 3 Although Germany shifted huge forces eastern western front signing treaty unable stop Allied advance especially entrance American troops 1918 4 war also chance combatant nations show military strength technological ingenuity Germans introduced machine gun 5 U boats 6 deadly gases 7 British first used tank 8 Both sides chance test new aircraft see could used warfare widely believed war short Unfortunately since trench warfare best form defense advances sides slow came terrible cost lives 9 Division Austria Hungary World War IWhen war finally 1918 results set stage next twenty years First foremost Germans forced sign Treaty Versailles forcing make exorbitant payments repair damages caused War Many Germans felt reparations unfair actually lose war feel caused war see Stab in the back legend 10 Germany never occupied Allied troops yet accept liberal democratic government imposed victors abdication Kaiser Wilhelm 11 Much map Europe redrawn victors based upon theory future wars could prevented ethnic groups homeland New states like Yugoslavia Czechoslovakia created former Austro Hungarian Empire accommodate nationalist aspirations groups 12 An international body called League Nations formed mediate disputes prevent future wars although effectiveness severely limited among things reluctance inability act 13 Russian Revolution communism Main article Russian RevolutionThe Russian Revolution 1917 ending overthrow Tsarist regime execution His Imperial Majesty Nicholas II family sparked wave communist revolutions across Europe prompting many believe socialist world revolution could realized near future 14 However European revolutions defeated Vladimir Lenin died 1924 within years Joseph Stalin displaced Leon Trotsky de facto leader Soviet Union idea worldwide revolution longer forefront Stalin concentrated socialism one country 15 embarked bold plan collectivization industrialization 16 majority socialists even many communists became disillusioned Stalin autocratic rule purges assassination enemies well news famines imposed people 17 Communism strengthened force Western democracies global economy crashed 1929 became known Great Depression Many people saw first stage end capitalist system attracted Communism solution economic crisis especially Soviet Union economic development 1930s strong unaffected capitalist world crisis 18 Between wars Dorothea Lange 1936 photo Migrant Mother one iconic photos associated Great Depressi ...

# %%
# Word tokenization
from nltk.tokenize import word_tokenize
tokenized_word_3 = word_tokenize(cleaned_text)
print(tokenized_word_3)
# Out:
# ['20th', 'century', 'changed', 'world', 'unprecedented', 'ways', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', '21st', 'century', 'today', 'Historic', 'events', '20th', 'century', 'World', 'beginning', 'century', 'Main', 'article', 'Edwardian', 'eraThe', 'new', 'beginning', '20th', 'century', 'marked', 'significant', 'changes', '1900s', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', '1914', 'saw', 'completion', 'Panama', 'Canal', 'From', '1914', '1918', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'war', 'end', 'wars', 'World', 'War', '1914', '1918', 'Main', 'article', 'World', 'War', 'IArrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'FerdinandThe', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'Great', 'War', 'contemporaries', 'started', 'July', '1914', 'ended', 'November', '1918', 'war', 'precipitated', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'member', 'Young', 'Bosnia', 'liberation', 'movement', 'After', 'period', 'diplomatic', 'military', 'escalation', 'known', 'July', 'Crisis', 'end', 'July', '1914', 'two', 'coalitions', 'war', 'Allies', 'comprised', 'initially', 'British', 'Empire', 'France', 'Russian', 'Empire', 'Central', 'Powers', 'comprised', 'initially', 'German', 'Empire', 'Austria', 'Hungary', '1', '2', '1917', 'Russia', 'ended', 'hostile', 'actions', 'Central', 'Powers', 'fall', 'Tsar', 'Bolsheviks', 'negotiated', 'Treaty', 'Brest', 'Litovsk', 'Germany', 'although', 'huge', 'cost', 'Russia', 'treaty', 'Bolshevik', 'Russia', 'ceded', 'Baltic', 'states', 'Germany', 'province', 'Kars', 'Oblast', 'South', 'Caucasus', 'Ottoman', 'Empire', 'also', 'recognized', 'independence', 'Ukraine', '3', 'Although', 'Germany', 'shifted', 'huge', 'forces', 'eastern', 'western', 'front', 'signing', 'treaty', 'unable', 'stop', 'Allied', 'advance', 'especially', 'entrance', 'American', 'troops', '1918', '4', 'war', 'also', 'chance', 'combatant', 'nations', 'show', 'military', 'strength', 'technological', 'ingenuity', 'Germans', 'introduced', 'machine', 'gun', '5', 'U', 'boats', '6', 'deadly', 'gases', '7', 'British', 'first', 'used', 'tank', '8', 'Both', 'sides', 'chance', 'test', 'new', 'aircraft', 'see', 'could', 'used', 'warfare', 'widely', 'believed', 'war', 'short', 'Unfortunately', 'since', 'trench', 'warfare', 'best', 'form', 'defense', 'advances', 'sides', 'slow', 'came', 'terrible', 'cost', 'lives', '9', 'Division', 'Austria', 'Hungary', 'World', 'War', 'IWhen', 'war', 'finally', '1918', 'results', 'set', 'stage', 'next', 'twenty', 'years', 'First', 'foremost', 'Germans', 'forced', 'sign', 'Treaty', 'Versailles', 'forcing', 'make', 'exorbitant', 'payments', 'repair', 'damages', 'caused', 'War', 'Many', 'Germans', 'felt', 'reparations', 'unfair', 'actually', 'lose', 'war', 'feel', 'caused', 'war', 'see', 'Stab', 'in', 'the', 'back', 'legend', '10', 'Germany', 'never', 'occupied', 'Allied', 'troops', 'yet', 'accept', 'liberal', 'democratic', 'government', 'imposed', 'victors', 'abdication', 'Kaiser', 'Wilhelm', '11', 'Much', 'map', 'Europe', 'redrawn', 'victors', 'based', 'upon', 'theory', 'future', 'wars', 'could', 'prevented', 'ethnic', 'groups', 'homeland', 'New', 'states', 'like', 'Yugoslavia', 'Czechoslovakia', 'created', 'former', 'Austro', 'Hungarian', 'Empire', 'accommodate', 'nationalist', 'aspirations', 'groups', '12', 'An', 'international', 'body', 'called', 'League', 'Nations', 'formed', 'mediate', 'disputes', 'prevent', 'future', 'wars', 'although', 'effectiveness',  ...

# %%
# Create a new FreqDist
dist_words_filter_2 = FreqDist(tokenized_word_3)
print(dist_words_filter_2)
# Out:
# <FreqDist with 3111 samples and 6932 outcomes>

# %%
# Check top 10 most common words in new filtered list
top10_filter_2 = dist_words_filter_2.most_common(10)
print(top10_filter_2)
# Out:
# [('war', 79), ('War', 55), ('Soviet', 49), ('Hitler', 39), ('first', 36), ('World', 33), ('world', 32), ('Germany', 32), ('German', 31), ('Japanese', 31)]

# %%
# Create a dataframe from new top 10 list
df_top10_filter_2 = pd.DataFrame(top10_filter_2, columns=['Word', 'Frequency'])
print(df_top10_filter_2)
# Out:
#        Word  Frequency
# 0       war         79
# 1       War         55
# 2    Soviet         49
# 3    Hitler         39
# 4     first         36
# 5     World         33
# 6     world         32
# 7   Germany         32
# 8    German         31
# 9  Japanese         31

# %%
# Create a bar chart of 10 most common words
plt.figure(figsize=(10, 6))
df_top10_filter_2.plot(kind='bar', x='Word', y='Frequency', legend=False, color='blue')
plt.title('Top 10 Most Common Words')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Without the stop words and punctuation, we get to see the actual words that are used most frequently in the 20th Century Events wiki page. This is far more representative of the content than the first frequency bar chart. The only issue is that "war" and "world" show up twice on the list, once with the first letter lowercase and once with the first letter uppercase. So, really the frequencies of "war" and "War" should be combined as well as "world" and "World". To do this I will convert all words to lowercase, except specific words like "US" (United States) so it doesn't get counted as the word "us".

# %%
# Defining special cases list to preserve their original case
special_cases = ['US']
# Convert words to lowercase based on conditions
processed_words = [word if word in special_cases else word.lower() for word in tokenized_word_3]

# %%
# Create a FreqDist of processed words
dist_words_processed = FreqDist(processed_words)
print(dist_words_processed)
# Out:
# <FreqDist with 2952 samples and 6932 outcomes>

# %%
# Check top 10 most common words in processed words list
top10_processed = dist_words_processed.most_common(10)
print(top10_processed)
# Out:
# [('war', 134), ('world', 65), ('soviet', 49), ('first', 39), ('hitler', 39), ('new', 33), ('germany', 32), ('german', 31), ('japanese', 31), ('states', 29)]

# %%
# Create a dataframe from processed top 10 list
df_top10_processed = pd.DataFrame(top10_processed, columns=['Word', 'Frequency'])
print(df_top10_processed)
# Out:
#        Word  Frequency
# 0       war        134
# 1     world         65
# 2    soviet         49
# 3     first         39
# 4    hitler         39
# 5       new         33
# 6   germany         32
# 7    german         31
# 8  japanese         31
# 9    states         29

# %%
# Create a bar chart of 10 most common words in processed list
plt.figure(figsize=(10, 6))
df_top10_processed.plot(kind='bar', x='Word', y='Frequency', legend=False, color='blue')
plt.title('Top 10 Most Common Words')
plt.xlabel('Words')
plt.ylabel('Frequency')

# Save figure
plt.savefig('10_most_common_words.png')

plt.show()

# %% [markdown]
# #### Now we have an accurate representation of the frequency of words in the wiki page, regardless of their capitalization. One insight we can already see from this bar chart is that there was a lot of war in the 20th century.

# %% [markdown]
# ## POS Tags with TextBlob

# %%
# Check time it will take to create TextBlob text
# %time
text = TextBlob(str(tokenized_word_3))
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Checking TextBlob text
text
# Out:
# TextBlob("['20th', 'century', 'changed', 'world', 'unprecedented', 'ways', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', '21st', 'century', 'today', 'Historic', 'events', '20th', 'century', 'World', 'beginning', 'century', 'Main', 'article', 'Edwardian', 'eraThe', 'new', 'beginning', '20th', 'century', 'marked', 'significant', 'changes', '1900s', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', '1914', 'saw', 'completion', 'Panama', 'Canal', 'From', '1914', '1918', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'war', 'end', 'wars', 'World', 'War', '1914', '1918', 'Main', 'article', 'World', 'War', 'IArrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'FerdinandThe', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'Great', 'War', 'contemporaries', 'started', 'July', '1914', 'ended', 'November', '1918', 'war', 'precipitated', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'member', 'Young', 'Bosnia', 'liberation', 'movement', 'After', 'period', 'diplomatic', 'military', 'escalation', 'known', 'July', 'Crisis', 'end', 'July', '1914', 'two', 'coalitions', 'war', 'Allies', 'comprised', 'initially', 'British', 'Empire', 'France', 'Russian', 'Empire', 'Central', 'Powers', 'comprised', 'initially', 'German', 'Empire', 'Austria', 'Hungary', '1', '2', '1917', 'Russia', 'ended', 'hostile', 'actions', 'Central', 'Powers', 'fall', 'Tsar', 'Bolsheviks', 'negotiated', 'Treaty', 'Brest', 'Litovsk', 'Germany', 'although', 'huge', 'cost', 'Russia', 'treaty', 'Bolshevik', 'Russia', 'ceded', 'Baltic', 'states', 'Germany', 'province', 'Kars', 'Oblast', 'South', 'Caucasus', 'Ottoman', 'Empire', 'also', 'recognized', 'independence', 'Ukraine', '3', 'Although', 'Germany', 'shifted', 'huge', 'forces', 'eastern', 'western', 'front', 'signing', 'treaty', 'unable', 'stop', 'Allied', 'advance', 'especially', 'entrance', 'American', 'troops', '1918', '4', 'war', 'also', 'chance', 'combatant', 'nations', 'show', 'military', 'strength', 'technological', 'ingenuity', 'Germans', 'introduced', 'machine', 'gun', '5', 'U', 'boats', '6', 'deadly', 'gases', '7', 'British', 'first', 'used', 'tank', '8', 'Both', 'sides', 'chance', 'test', 'new', 'aircraft', 'see', 'could', 'used', 'warfare', 'widely', 'believed', 'war', 'short', 'Unfortunately', 'since', 'trench', 'warfare', 'best', 'form', 'defense', 'advances', 'sides', 'slow', 'came', 'terrible', 'cost', 'lives', '9', 'Division', 'Austria', 'Hungary', 'World', 'War', 'IWhen', 'war', 'finally', '1918', 'results', 'set', 'stage', 'next', 'twenty', 'years', 'First', 'foremost', 'Germans', 'forced', 'sign', 'Treaty', 'Versailles', 'forcing', 'make', 'exorbitant', 'payments', 'repair', 'damages', 'caused', 'War', 'Many', 'Germans', 'felt', 'reparations', 'unfair', 'actually', 'lose', 'war', 'feel', 'caused', 'war', 'see', 'Stab', 'in', 'the', 'back', 'legend', '10', 'Germany', 'never', 'occupied', 'Allied', 'troops', 'yet', 'accept', 'liberal', 'democratic', 'government', 'imposed', 'victors', 'abdication', 'Kaiser', 'Wilhelm', '11', 'Much', 'map', 'Europe', 'redrawn', 'victors', 'based', 'upon', 'theory', 'future', 'wars', 'could', 'prevented', 'ethnic', 'groups', 'homeland', 'New', 'states', 'like', 'Yugoslavia', 'Czechoslovakia', 'created', 'former', 'Austro', 'Hungarian', 'Empire', 'accommodate', 'nationalist', 'aspirations', 'groups', '12', 'An', 'international', 'body', 'called', 'League', 'Nations', 'formed', 'mediate', 'disputes', 'prevent', 'future', 'wars', 'although', 'effect ...

# %%
# Adding tags to the list
tags_list = text.tags

# %%
# Reviewing tags_list
tags_list
# Out:
# [('[', 'JJ'),
#  ("'20th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'changed", 'VBD'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'unprecedented", 'VBD'),
#  ("'ways", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Wars", 'NNS'),
#  ("'", 'POS'),
#  ("'sparked", 'VBD'),
#  ("'tension", 'NNP'),
#  ("'", 'POS'),
#  ("'countries", 'NNS'),
#  ("'", 'POS'),
#  ("'led", 'VBD'),
#  ("'creation", 'NNP'),
#  ("'", 'POS'),
#  ("'atomic", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'led", 'VBD'),
#  ("'Space", 'NNP'),
#  ("'", 'POS'),
#  ("'Race", 'NNP'),
#  ("'", 'POS'),
#  ("'creation", 'NN'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'rockets", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Wide", 'NNP'),
#  ("'", 'POS'),
#  ("'Web", 'NNP'),
#  ("'", 'POS'),
#  ("'created", 'VBD'),
#  ("'These", 'JJ'),
#  ("'advancements", 'NNS'),
#  ("'", 'POS'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'role", 'NNP'),
#  ("'", 'POS'),
#  ("'citizens", 'NNS'),
#  ("'", 'POS'),
#  ("'lives", 'NNS'),
#  ("'", 'POS'),
#  ("'shaped", 'VBD'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Historic", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'20th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Edwardian", 'JJ'),
#  ("'eraThe", 'NNP'),
#  ("'", 'POS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'20th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'marked", 'VBD'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'changes", 'NNS'),
#  ("'", 'POS'),
#  ("'1900s", 'NNP'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'herald", 'NNP'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'inventions", 'NNS'),
#  ("'", 'POS'),
#  ("'including", 'VBG'),
#  ("'automobile", 'IN'),
#  ("'airplane", 'NNP'),
#  ("'", 'POS'),
#  ("'radio", 'NNP'),
#  ("'", 'POS'),
#  ("'broadcasting", 'VBG'),
#  ("'1914", 'NNP'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'completion", 'NN'),
#  ("'Panama", 'NNP'),
#  ("'", 'POS'),
#  ("'Canal", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'1914", 'NNP'),
#  ("'", 'POS'),
#  ("'1918", 'NNP'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'aftermath", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'changes", 'NNS'),
#  ("'", 'POS'),
#  ("'power", 'NNP'),
#  ("'", 'POS'),
#  ("'balance", 'NN'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'destroying", 'VBG'),
#  ("'transforming", 'VBG'),
#  ("'empires", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'1914", 'NNP'),
#  ("'", 'POS'),
#  ("'1918", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'IArrest", 'JJS'),
#  ("'suspect", 'NNP'),
#  ("'", 'POS'),
#  ("'Sarajevo", 'NNP'),
#  ("'", 'POS'),
#  ("'following", 'VBG'),
#  ("'Assassination", 'NNP'),
#  ("'", 'POS'),
#  ("'Archduke", 'NNP'),
#  ("'", 'POS'),
#  ("'Franz", 'NNP'),
#  ("'", 'POS'),
#  ("'FerdinandThe", 'NNP'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'simply", 'NNP'),
#  ("'", 'POS'),
#  ("'WWI", 'NNP'),
#  ("'", 'POS'),
#  ("'termed", 'VBD'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'contemporaries", 'NNS'),
#  ("'", 'POS'),
#  ("'started", 'VBD'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'1914", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'November", 'NNP'),
#  ("'", 'POS'),
#  ("'1918", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'precipitated", 'VBD'),
#  ("'Assassination", 'NNP'),
#  ("'", 'POS'),
#  ("'Sarajevo", 'NNP'),
#  ("'", 'POS'),
#  ("'Austro", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungarian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'throne", 'CD'),
#  ("'Erzherzog", 'NNP'),
#  ("'", 'POS'),
#  ("'Franz", 'NNP'),
#  ("'", 'POS'),
#  ("'Ferdinand", 'NNP'),
#  ("'", 'POS'),
#  ("'Gavrilo", 'NNP'),
#  ("'", 'POS'),
#  ("'Princip", 'NNP'),
#  ("'", 'POS'),
#  ("'member", 'NNP'),
#  ("'", 'POS'),
#  ("'Young", 'NNP'),
#  ("'", 'POS'),
#  ("'Bosnia", 'NNP'),
#  ("'", 'POS'),
#  ("'liberation", 'NN'),
#  ("'movement", 'NNP'),
#  ("'", 'POS'),
#  ("'After", 'NNP'),
#  ("'", 'POS'),
#  ("'period", 'NNP'),
#  ("'", 'POS'),
#  ("'diplomatic", 'JJ'),
#  ("'military", 'NNP'),
#  ("'", 'POS'),
#  ("'escalation", 'NN'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'Crisis", 'NN'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'1914", 'NNP'),
#  ("'", 'POS'),
#  ("'two", 'NNP'),
#  ("'", 'POS'),
#  ("'coalitions", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Allies", 'NNS'),
#  ("'", 'POS'),
#  ("'comprised", 'VBD'),
#  ("'initially", 'RB'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'France", 'NN'),
#  ("'Russian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'Central", 'NNP'),
#  ("'", 'POS'),
#  ("'Powers", 'NNS'),
#  ("'", 'POS'),
#  ("'comprised", 'VBD'),
#  ("'initially", 'RB'),
#  ("'", 'POS'),
#  ("'German", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'Austria", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungary", 'NNP'),
#  ("'", 'POS'),
#  ('1', 'CD'),
#  ('2', 'CD'),
#  ("'1917", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'hostile", 'IN'),
#  ("'actions", 'NNS'),
#  ("'", 'POS'),
#  ("'Central", 'NNP'),
#  ("'", 'POS'),
#  ("'Powers", 'NNS'),
#  ("'", 'POS'),
#  ("'Tsar", 'NNP'),
#  ("'", 'POS'),
#  ("'Bolsheviks", 'NNP'),
#  ("'", 'POS'),
#  ("'negotiated", 'VBD'),
#  ("'Treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Brest", 'JJS'),
#  ("'Litovsk", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'cost", 'FW'),
#  ("'", 'POS'),
#  ("'treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Bolshevik", 'NNP'),
#  ("'", 'POS'),
#  ("'ceded", 'VBD'),
#  ("'Baltic", 'JJ'),
#  ("'states", 'VBZ'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'province", 'NN'),
#  ("'Kars", 'NNS'),
#  ("'", 'POS'),
#  ("'South", 'NNP'),
#  ("'", 'POS'),
#  ("'Caucasus", 'NNP'),
#  ("'", 'POS'),
#  ("'Ottoman", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'recognized", 'VBN'),
#  ("'independence", 'NNP'),
#  ("'", 'POS'),
#  ("'Ukraine", 'NNP'),
#  ("'", 'POS'),
#  ('3', 'CD'),
#  ("'Although", 'IN'),
#  ("'", 'POS'),
#  ("'shifted", 'VBD'),
#  ("'forces", 'NNS'),
#  ("'", 'POS'),
#  ("'eastern", 'NNP'),
#  ("'", 'POS'),
#  ("'western", 'NNP'),
#  ("'", 'POS'),
#  ("'front", 'NNP'),
#  ("'", 'POS'),
#  ("'signing", 'VBG'),
#  ("'treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'unable", 'JJ'),
#  ("'stop", 'NNP'),
#  ("'", 'POS'),
#  ("'Allied", 'VBD'),
#  ("'advance", 'NNP'),
#  ("'", 'POS'),
#  ("'especially", 'RB'),
#  ("'", 'POS'),
#  ("'entrance", 'NN'),
#  ("'American", 'JJ'),
#  ("'troops", 'NNS'),
#  ("'", 'POS'),
#  ("'1918", 'NNP'),
#  ("'", 'POS'),
#  ('4', 'CD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'chance", 'NN'),
#  ("'combatant", 'NNP'),
#  ("'", 'POS'),
#  ("'nations", 'NNS'),
#  ("'", 'POS'),
#  ("'show", 'NNP'),
#  ("'", 'POS'),
#  ("'military", 'NNP'),
#  ("'", 'POS'),
#  ("'strength", 'NNP'),
#  ("'", 'POS'),
#  ("'technological", 'JJ'),
#  ("'ingenuity", 'NNP'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'introduced", 'VBD'),
#  ("'machine", 'NNP'),
#  ("'", 'POS'),
#  ("'gun", 'NNP'),
#  ("'", 'POS'),
#  ('5', 'CD'),
#  ('U', 'NNP'),
#  ("'", 'POS'),
#  ("'boats", 'NNS'),
#  ("'", 'POS'),
#  ('6', 'CD'),
#  ("'deadly", 'RB'),
#  ("'gases", 'NNS'),
#  ("'", 'POS'),
#  ('7', 'CD'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ("'used", 'VBD'),
#  ("'tank", 'NNP'),
#  ("'", 'POS'),
#  ('8', 'CD'),
#  ("'Both", 'DT'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'chance", 'NN'),
#  ("'test", 'JJS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'aircraft", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'used", 'VBD'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'widely", 'RB'),
#  ("'believed", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'short", 'NNP'),
#  ("'", 'POS'),
#  ("'Unfortunately", 'RB'),
#  ("'since", 'NNP'),
#  ("'", 'POS'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'best", 'JJS'),
#  ("'advances", 'NNS'),
#  ("'", 'POS'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'slow", 'NNP'),
#  ("'", 'POS'),
#  ("'terrible", 'JJ'),
#  ("'cost", 'FW'),
#  ("'", 'POS'),
#  ("'lives", 'NNS'),
#  ("'", 'POS'),
#  ('9', 'CD'),
#  ("'Division", 'NNP'),
#  ("'", 'POS'),
#  ("'Austria", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungary", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'IWhen", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'finally", 'RB'),
#  ("'", 'POS'),
#  ("'1918", 'NNP'),
#  ("'", 'POS'),
#  ("'results", 'NNS'),
#  ("'", 'POS'),
#  ("'set", 'NNP'),
#  ("'", 'POS'),
#  ("'stage", 'NN'),
#  ("'twenty", 'NNP'),
#  ("'", 'POS'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'foremost", 'FW'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'forced", 'VBD'),
#  ("'sign", 'NNP'),
#  ("'", 'POS'),
#  ("'Treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Versailles", 'NNS'),
#  ("'", 'POS'),
#  ("'forcing", 'VBG'),
#  ("'make", 'NNP'),
#  ("'", 'POS'),
#  ("'exorbitant", 'NNP'),
#  ("'", 'POS'),
#  ("'payments", 'NNS'),
#  ("'", 'POS'),
#  ("'repair", 'NNP'),
#  ("'", 'POS'),
#  ("'damages", 'NNS'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'felt", 'NNP'),
#  ("'", 'POS'),
#  ("'reparations", 'NNS'),
#  ("'", 'POS'),
#  ("'unfair", 'NNP'),
#  ("'", 'POS'),
#  ("'actually", 'RB'),
#  ("'", 'POS'),
#  ("'lose", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'feel", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'in", 'NNP'),
#  ("'", 'POS'),
#  ("'the", 'NNP'),
#  ("'", 'POS'),
#  ("'10", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'occupied", 'VBD'),
#  ("'Allied", 'VBD'),
#  ("'troops", 'NNS'),
#  ("'", 'POS'),
#  ("'yet", 'NNP'),
#  ("'", 'POS'),
#  ("'accept", 'IN'),
#  ("'liberal", 'NNP'),
#  ("'", 'POS'),
#  ("'democratic", 'JJ'),
#  ("'government", 'NNP'),
#  ("'", 'POS'),
#  ("'imposed", 'VBD'),
#  ("'victors", 'NNS'),
#  ("'", 'POS'),
#  ("'abdication", 'NN'),
#  ("'Kaiser", 'NNP'),
#  ("'", 'POS'),
#  ("'Wilhelm", 'NNP'),
#  ("'", 'POS'),
#  ("'11", 'NNP'),
#  ("'", 'POS'),
#  ("'Much", 'JJ'),
#  ("'map", 'NNP'),
#  ("'", 'POS'),
#  ("'redrawn", 'NNP'),
#  ("'", 'POS'),
#  ("'victors", 'NNS'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'theory", 'NNP'),
#  ("'", 'POS'),
#  ("'future", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'prevented", 'VBD'),
#  ("'ethnic", 'NNP'),
#  ("'", 'POS'),
#  ("'groups", 'NNS'),
#  ("'", 'POS'),
#  ("'homeland", 'NNP'),
#  ("'", 'POS'),
#  ("'New", 'NNP'),
#  ("'", 'POS'),
#  ("'states", 'NNS'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ("'Yugoslavia", 'NNP'),
#  ("'", 'POS'),
#  ("'Czechoslovakia", 'NNP'),
#  ("'", 'POS'),
#  ("'created", 'VBD'),
#  ("'Austro", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungarian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'accommodate", 'NNP'),
#  ("'", 'POS'),
#  ("'aspirations", 'NNS'),
#  ("'", 'POS'),
#  ("'groups", 'NNS'),
#  ("'", 'POS'),
#  ("'12", 'NNP'),
#  ("'", 'POS'),
#  ("'An", 'NNP'),
#  ("'", 'POS'),
#  ("'international", 'NNP'),
#  ("'", 'POS'),
#  ("'body", 'NN'),
#  ("'called", 'VBD'),
#  ("'League", 'NNP'),
#  ("'", 'POS'),
#  ("'Nations", 'NNS'),
#  ("'", 'POS'),
#  ("'formed", 'VBD'),
#  ("'mediate", 'NNP'),
#  ("'", 'POS'),
#  ("'disputes", 'NNS'),
#  ("'", 'POS'),
#  ("'prevent", 'NNP'),
#  ("'", 'POS'),
#  ("'future", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'effectiveness", 'NNP'),
#  ("'", 'POS'),
#  ("'severely", 'RB'),
#  ("'limited", 'VBD'),
#  ("'among", 'NNP'),
#  ("'", 'POS'),
#  ("'things", 'NNS'),
#  ("'", 'POS'),
#  ("'reluctance", 'NN'),
#  ("'inability", 'NNP'),
#  ("'", 'POS'),
#  ("'act", 'NNP'),
#  ("'", 'POS'),
#  ("'13", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'communism", 'NN'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'RevolutionThe", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'1917", 'NNP'),
#  ("'", 'POS'),
#  ("'ending", 'VBG'),
#  ("'regime", 'NNP'),
#  ("'", 'POS'),
#  ("'execution", 'NN'),
#  ("'His", 'NNP'),
#  ("'", 'POS'),
#  ("'Imperial", 'NNP'),
#  ("'", 'POS'),
#  ("'Majesty", 'NNP'),
#  ("'", 'POS'),
#  ("'Nicholas", 'NNS'),
#  ("'", 'POS'),
#  ("'II", 'NNP'),
#  ("'", 'POS'),
#  ("'family", 'RB'),
#  ("'", 'POS'),
#  ("'sparked", 'VBD'),
#  ("'wave", 'NNP'),
#  ("'", 'POS'),
#  ("'revolutions", 'NNS'),
#  ("'", 'POS'),
#  ("'across", 'IN'),
#  ("'prompting", 'VBG'),
#  ("'", 'POS'),
#  ("'believe", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'revolution", 'NN'),
#  ("'could", 'MD'),
#  ("'realized", 'VBN'),
#  ("'near", 'IN'),
#  ("'future", 'NN'),
#  ("'14", 'NNP'),
#  ("'", 'POS'),
#  ("'revolutions", 'NNS'),
#  ("'", 'POS'),
#  ("'defeated", 'VBD'),
#  ("'Vladimir", 'NNP'),
#  ("'", 'POS'),
#  ("'Lenin", 'NNP'),
#  ("'", 'POS'),
#  ("'died", 'VBD'),
#  ("'1924", 'NNP'),
#  ("'", 'POS'),
#  ("'within", 'NNP'),
#  ("'", 'POS'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'Joseph", 'NNP'),
#  ("'", 'POS'),
#  ("'Stalin", 'NNP'),
#  ("'", 'POS'),
#  ("'displaced", 'VBD'),
#  ("'Leon", 'NNP'),
#  ("'", 'POS'),
#  ("'Trotsky", 'NNP'),
#  ("'", 'POS'),
#  ("'de", 'NNP'),
#  ("'", 'POS'),
#  ("'facto", 'NNP'),
#  ("'", 'POS'),
#  ("'Soviet", 'NNP'),
#  ("'", 'POS'),
#  ("'Union", 'NN'),
#  ("'idea", 'NNP'),
#  ("'", 'POS'),
#  ("'worldwide", 'NNP'),
#  ("'", 'POS'),
#  ("'revolution", 'NN'),
#  ("'longer", 'NNP'),
#  ("'", 'POS'),
#  ("'forefront", 'NNP'),
#  ("'", 'POS'),
#  ("'Stalin", 'NNP'),
#  ("'", 'POS'),
#  ("'concentrated", 'VBD'),
#  ("'socialism", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'country", 'NNP'),
#  ("'", 'POS'),
#  ("'15", 'NNP'),
#  ("'", 'POS'),
#  ("'embarked", 'VBD'),
#  ("'plan", 'NNP'),
#  ("'", 'POS'),
#  ("'collectivization", 'NN'),
#  ("'industrialization", 'NNP'),
#  ("'", 'POS'),
#  ("'16", 'NNP'),
#  ("'", 'POS'),
#  ("'majority", 'NNP'),
#  ("'", 'POS'),
#  ("'socialists", 'NNS'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'communists", 'NNS'),
#  ("'", 'POS'),
#  ("'disillusioned", 'VBD'),
#  ("'Stalin", 'NNP'),
#  ("'", 'POS'),
#  ("'autocratic", 'JJ'),
#  ("'rule", 'NNP'),
#  ("'", 'POS'),
#  ("'purges", 'NNS'),
#  ("'", 'POS'),
#  ("'assassination", 'NN'),
#  ("'enemies", 'NNS'),
#  ("'", 'POS'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'news", 'NNS'),
#  ("'", 'POS'),
#  ("'famines", 'NNS'),
#  ("'", 'POS'),
#  ("'imposed", 'VBD'),
#  ("'17", 'NNP'),
#  ("'", 'POS'),
#  ("'Communism", 'NN'),
#  ("'strengthened", 'VBD'),
#  ("'force", 'NNP'),
#  ("'", 'POS'),
#  ("'Western", 'NNP'),
#  ("'", 'POS'),
#  ("'democracies", 'NNS'),
#  ("'", 'POS'),
#  ("'economy", 'NNP'),
#  ("'", 'POS'),
#  ("'crashed", 'VBD'),
#  ("'1929", 'NNP'),
#  ("'", 'POS'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'Depression", 'NN'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ("'stage", 'NN'),
#  ("'system", 'NNP'),
#  ("'", 'POS'),
#  ("'attracted", 'VBD'),
#  ("'Communism", 'NNP'),
#  ("'", 'POS'),
#  ("'solution", 'NN'),
#  ("'economic", 'NNP'),
#  ("'", 'POS'),
#  ("'crisis", 'NN'),
#  ("'especially", 'RB'),
#  ("'", 'POS'),
#  ("'Soviet", 'NNP'),
#  ("'", 'POS'),
#  ("'Union", 'NN'),
#  ("'economic", 'NNP'),
#  ("'", 'POS'),
#  ("'development", 'NNP'),
#  ("'", 'POS'),
#  ("'1930s", 'NNP'),
#  ("'", 'POS'),
#  ("'strong", 'NNP'),
#  ("'", 'POS'),
#  ("'unaffected", 'VBD'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'crisis", 'NN'),
#  ("'18", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'Dorothea", 'NNP'),
#  ("'", 'POS'),
#  ("'Lange", 'NNP'),
#  ("'", 'POS'),
#  ("'1936", 'NNP'),
#  ("'", 'POS'),
#  ("'Migrant", 'NNP'),
#  ("'", 'POS'),
#  ("'Mother", 'PRP'),
#  ("'one", 'CD'),
#  ("'iconic", 'NNP'),
#  ("'", 'POS'),
#  ("'photos", 'NNS'),
#  ("'", 'POS'),
#  ("'associated", 'VBD'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Interwar", 'NNP'),
#  ("'", 'POS'),
#  ("'periodEconomic", 'NNP'),
#  ("'", 'POS'),
#  ("'depression", 'NN'),
#  ("'articles", 'NNS'),
#  ("'", 'POS'),
#  ("'Roaring", 'VBG'),
#  ("'Twenties", 'NNS'),
#  ("'", 'POS'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'DepressionAfter", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'economy", 'NNP'),
#  ("'", 'POS'),
#  ("'remained", 'VBD'),
#  ("'strong", 'NNP'),
#  ("'", 'POS'),
#  ("'1920s", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'provided", 'VBD'),
#  ("'stimulus", 'CC'),
#  ("'industry", 'NNP'),
#  ("'", 'POS'),
#  ("'economic", 'NNP'),
#  ("'", 'POS'),
#  ("'activity", 'NNP'),
#  ("'", 'POS'),
#  ("'general", 'NNP'),
#  ("'", 'POS'),
#  ("'There", 'EX'),
#  ("'", 'POS'),
#  ("'warning", 'VBG'),
#  ("'signs", 'NNS'),
#  ("'", 'POS'),
#  ("'foretelling", 'VBG'),
#  ("'crash", 'NNP'),
#  ("'", 'POS'),
#  ("'29", 'NNP'),
#  ("'", 'POS'),
#  ("'economic", 'NNP'),
#  ("'", 'POS'),
#  ("'system", 'NNP'),
#  ("'", 'POS'),
#  ("'generally", 'RB'),
#  ("'", 'POS'),
#  ("'understood", 'NNP'),
#  ("'", 'POS'),
#  ("'political", 'JJ'),
#  ("'time", 'NNP'),
#  ("'", 'POS'),
#  ("'19", 'NNP'),
#  ("'", 'POS'),
#  ("'responses", 'NNS'),
#  ("'", 'POS'),
#  ("'crisis", 'NN'),
#  ("'situation", 'NNP'),
#  ("'", 'POS'),
#  ("'millions", 'NNS'),
#  ("'", 'POS'),
#  ("'watched", 'VBD'),
#  ("'savings", 'NNS'),
#  ("'", 'POS'),
#  ("'become", 'NNP'),
#  ("'", 'POS'),
#  ("'worthless", 'NNP'),
#  ("'", 'POS'),
#  ("'idea", 'NNP'),
#  ("'", 'POS'),
#  ("'job", 'NNP'),
#  ("'", 'POS'),
#  ("'reasonable", 'JJ'),
#  ("'income", 'NNP'),
#  ("'", 'POS'),
#  ("'fading", 'VBG'),
#  ("'away", 'NNP'),
#  ("'", 'POS'),
#  ("'20", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'sought", 'NNP'),
#  ("'", 'POS'),
#  ("'answers", 'NNS'),
#  ("'", 'POS'),
#  ("'alternative", 'CD'),
#  ("'ideologies", 'NNS'),
#  ("'", 'POS'),
#  ("'communism", 'NN'),
#  ("'fascism", 'NNP'),
#  ("'", 'POS'),
#  ("'21", 'NNP'),
#  ("'", 'POS'),
#  ("'They", 'NNP'),
#  ("'", 'POS'),
#  ("'believed", 'VBD'),
#  ("'economic", 'NNP'),
#  ("'", 'POS'),
#  ("'system", 'NNP'),
#  ("'", 'POS'),
#  ("'collapsing", 'VBG'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'ideas", 'NNS'),
#  ("'", 'POS'),
#  ("'required", 'VBD'),
#  ("'meet", 'NNP'),
#  ("'", 'POS'),
#  ("'crisis", 'NN'),
#  ("'early", 'RB'),
#  ("'responses", 'NNS'),
#  ("'", 'POS'),
#  ("'crisis", 'NN'),
#  ("'based", 'VBD'),
#  ("'assumption", 'NNP'),
#  ("'", 'POS'),
#  ("'market", 'NNP'),
#  ("'", 'POS'),
#  ("'correct", 'NNP'),
#  ("'", 'POS'),
#  ("'This", 'NNP'),
#  ("'", 'POS'),
#  ("'little", 'NNP'),
#  ("'", 'POS'),
#  ("'correct", 'NNP'),
#  ("'", 'POS'),
#  ("'crisis", 'NN'),
#  ("'alleviate", 'NNP'),
#  ("'", 'POS'),
#  ("'suffering", 'VBG'),
#  ("'", 'POS'),
#  ("'ordinary", 'NNP'),
#  ("'", 'POS'),
#  ("'idea", 'NNP'),
#  ("'", 'POS'),
#  ("'existing", 'VBG'),
#  ("'system", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'reformed", 'VBD'),
#  ("'government", 'NNP'),
#  ("'", 'POS'),
#  ("'intervention", 'NN'),
#  ("'economy", 'NNP'),
#  ("'", 'POS'),
#  ("'rather", 'PRP'),
#  ("'continuing", 'VBG'),
#  ("'laissez", 'NNP'),
#  ("'", 'POS'),
#  ("'faire", 'NNP'),
#  ("'", 'POS'),
#  ("'approach", 'NNP'),
#  ("'", 'POS'),
#  ("'prominent", 'NNP'),
#  ("'", 'POS'),
#  ("'solution", 'NN'),
#  ("'Democratic", 'JJ'),
#  ("'governments", 'NNS'),
#  ("'", 'POS'),
#  ("'assumed", 'VBD'),
#  ("'responsibility", 'NNP'),
#  ("'", 'POS'),
#  ("'provide", 'NNP'),
#  ("'", 'POS'),
#  ...]

# %%
# Create a dataframe of the words and their types
df_text = pd.DataFrame(tags_list)
df_text.columns = ['Words', "Word type"]

# %%
# Checking dataframe
df_text.head()
# Out:
#       Words Word type
# 0         [        JJ
# 1     '20th       NNP
# 2         '       POS
# 3  'century       NNP
# 4         '       POS

# %%
# Grouping dataframe by word type to get counts
df_t = df_text.groupby('Word type').count().reset_index()

# %%
# Checking grouped dataframe
df_t.head()
# Out:
#   Word type  Words
# 0        CC      1
# 1        CD    117
# 2        DT     10
# 3        EX      8
# 4        FW     29

# %%
# Finding top 10 POS tags
pos_top10 = df_t.nlargest(10, 'Words')

# %%
# Plotting bar chart for top 10 POS tags
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 20):
    sns.barplot(x = "Words", y = "Word type",
    saturation = 0.9, data = pos_top10).set_title("20th Century Events - top 10 word types used")

# Save figure
plt.savefig('top_10_word_types.png')

# %% [markdown]
# #### The most used word type is POS, which stands for words with possessive endings. This makes sense as the context of the wiki page would explain how a certain country's or person's influence affected an event in the 20th century. However, I didn't expect it to be the highest. Next, is NNP (proper nouns). This is the one that I thought would be the highest since this text is talking about countries, people, and names of events that occurred. NNS (plural nouns) and VBD (past tense verbs) are next on the list but not closely behind.

# %% [markdown]
# ## Nouns

# %%
# Creating df of nouns and their occurrences then finding top 15
df_nouns = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNP") | (df_text['Word type'] == "NNPS")]
df_nouns.columns = ["Word", "Occurrences"]
# Remove leading apostrophes
df_nouns['Word'] = df_nouns['Word'].str.lstrip("'")
# Grouoing by 'Word' and counting occurrences
x = df_nouns.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurrences'], ascending=False)
top15_nouns = y.nlargest(15, 'Occurrences')
# Out:
# C:\Users\jboer\AppData\Local\Temp\ipykernel_64344\3246085584.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nouns['Word'] = df_nouns['Word'].str.lstrip("'")

# %%
# Checking top15_nouns list
top15_nouns
# Out:
#          Word  Occurrences
# 1938      war           79
# 845       War           55
# 781    Soviet           49
# 539    Hitler           39
# 1257    first           36
# 860     World           33
# 1962    world           32
# 507    German           31
# 508   Germans           29
# 830     Union           28
# 913      also           27
# 1021  century           23
# 1945  weapons           23
# 1524      new           22
# 824         U           20

# %%
# Plotting a bar chart of the most frequently used nouns
plt.figure(figsize=(15, 6))
with sns.dark_palette("xkcd:blue", 15):
    sns.barplot(x="Word", y="Occurrences",
    saturation=0.9, data = top15_nouns).set_title("20th Century Events - most frequently used nouns")

# Save figure
plt.savefig('most_frequent_nouns.png')

# %% [markdown]
# #### Since we are analyzing the part of speech, I couldn't change the case of the words as it would affect the recognition of the correct part of speech (proper noun or noun), which is why there is "war" and "War" as well as "world" and "World". The "U" likely stands for US or USA but was separated from the other letters when I removed the punctuation. Aside from that, based on these frequencies, we can get an idea of things that happened and key players in 20th century events. For example, we can clearly see that "war" was big part of the 20th century and that there were a lot of "first"s that happened, whether that be in relation to the "wars" or possibly "new" "weapons", and that these events affected the entire "world". This chart also shows the key players in the events of the 20th century, "Soviet" "Union", "Hitler", "German(s)", "US".

# %% [markdown]
# ## Verbs

# %%
# Creating df of verbs and their occurrences then finding top 15
df_verbs = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD") | (df_text['Word type'] == "VBG") | (df_text['Word type'] == "VBN")]
df_verbs.columns = ["Word", "Occurrences"]
# Remove leading apostrophes
df_verbs['Word'] = df_verbs['Word'].str.lstrip("'")
# Grouping by 'Word' and counting occurrences
x = df_verbs.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurrences'], ascending=False)
top15_verbs = y.nlargest(15, 'Occurrences')
# Out:
# C:\Users\jboer\AppData\Local\Temp\ipykernel_64344\435659949.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_verbs['Word'] = df_verbs['Word'].str.lstrip("'")

# %%
# Checking top15_verbs list
top15_verbs
# Out:
#             Word  Occurrences
# 14        United           26
# 0         Allied           18
# 264          led           15
# 452         used           13
# 260     launched           11
# 228    including            9
# 200       forced            8
# 102   controlled            8
# 442       turned            7
# 425  surrendered            7
# 56     beginning            7
# 261      leading            7
# 110      created            6
# 61       bombing            6
# 290     occupied            6

# %%
# Plotting a bar chart of the most frequently used verbs
plt.figure(figsize=(15, 6))
with sns.dark_palette("xkcd:red", 15):
    sns.barplot(x="Word", y="Occurrences",
    saturation=0.9, data = top15_verbs).set_title("20th Century Events - most frequently used verbs")

# Save figure
plt.savefig('most_frequent_verbs.png')

# %% [markdown]
# #### Looking at the most frequently used verbs I think there is a little confusion with "United" and "Allied". While the words themselves can be past tense verbs, in the context they are being used they would be considered adjectives or even part of a proper noun "United States", "Allied Nations". Apart from that, the rest of the most frequently used verbs are words associated with war, "led", "launched", "forced", "controlled", "surrendered", "bombing". This again tells us that the 20th century was filled with conflict.

# %% [markdown]
# ## Adjectives

# %%
# Creating df of adjectives and their occurrences then finding top 15
df_adj = df_text[(df_text['Word type'] == "JJ") | (df_text['Word type'] == "JJR") | (df_text['Word type'] == "JJS")]
df_adj.columns = ["Word", "Occurrences"]
# Remove leading apostrophes
df_adj['Word'] = df_adj['Word'].str.lstrip("'")
# Grouping by 'Word' and counting occurrences
x = df_adj.groupby('Word').count().reset_index()
y = x.sort_values(by=['Occurrences'], ascending=False)
top15_adj = y.nlargest(15, 'Occurrences')
# Out:
# C:\Users\jboer\AppData\Local\Temp\ipykernel_64344\1700102174.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adj['Word'] = df_adj['Word'].str.lstrip("'")

# %%
# Checking top15_adj list
top15_adj
# Out:
#           Word  Occurrences
# 20    Japanese           31
# 2     American           16
# 36        West            9
# 96       power            8
# 77     largest            7
# 12     Chinese            7
# 95    possible            5
# 28     Russian            5
# 94   political            5
# 103       rest            4
# 82     medical            4
# 31       These            4
# 4     Atlantic            4
# 47   bloodiest            3
# 115     unable            3

# %%
# Plotting a bar chart of the most frequently used adjectives
plt.figure(figsize=(15, 6))
with sns.dark_palette("xkcd:green", 15):
    sns.barplot(x="Word", y="Occurrences",
    saturation=0.9, data = top15_adj).set_title("20th Century Events - most frequently used adjectives")

# Save figure
plt.savefig('most_frequent_adjs.png')

# %% [markdown]
# #### Here we are given a look at more key players in the 20th century, i.e. "Japanese", "American", "Chinese", "Russian", "Australian". These most frequent adjectives can also give us an idea of the potential reasonsa and results behind some of the conflicts and wars that we discovered earlier. For example, "power", "political", "medical", "bloodiest". Aside from the actual names of the countries, the terms "

# %% [markdown]
# ## Counting Country Occurrences

# %%
# Create a single string of text
listToStr = ' '.join([str(elem) for elem in filtered_words_2])
print(listToStr)
# Out:
# 20th century changed world unprecedented ways World Wars sparked tension countries led creation atomic bombs Cold War led Space Race creation space based rockets World Wide Web created These advancements played significant role citizens lives shaped 21st century today Historic events 20th century World beginning century Main article Edwardian eraThe new beginning 20th century marked significant changes 1900s saw decade herald series inventions including automobile airplane radio broadcasting 1914 saw completion Panama Canal From 1914 1918 First World War aftermath caused major changes power balance world destroying transforming powerful empires war end wars World War 1914 1918 Main article World War IArrest suspect Sarajevo following Assassination Archduke Franz FerdinandThe First World War simply WWI termed Great War contemporaries started July 1914 ended November 1918 war precipitated Assassination Sarajevo Austro Hungarian Empire heir throne Erzherzog Franz Ferdinand Gavrilo Princip member Young Bosnia liberation movement After period diplomatic military escalation known July Crisis end July 1914 two coalitions war Allies comprised initially British Empire France Russian Empire Central Powers comprised initially German Empire Austria Hungary 1 2 1917 Russia ended hostile actions Central Powers fall Tsar Bolsheviks negotiated Treaty Brest Litovsk Germany although huge cost Russia treaty Bolshevik Russia ceded Baltic states Germany province Kars Oblast South Caucasus Ottoman Empire also recognized independence Ukraine 3 Although Germany shifted huge forces eastern western front signing treaty unable stop Allied advance especially entrance American troops 1918 4 war also chance combatant nations show military strength technological ingenuity Germans introduced machine gun 5 U boats 6 deadly gases 7 British first used tank 8 Both sides chance test new aircraft see could used warfare widely believed war short Unfortunately since trench warfare best form defense advances sides slow came terrible cost lives 9 Division Austria Hungary World War IWhen war finally 1918 results set stage next twenty years First foremost Germans forced sign Treaty Versailles forcing make exorbitant payments repair damages caused War Many Germans felt reparations unfair actually lose war feel caused war see Stab in the back legend 10 Germany never occupied Allied troops yet accept liberal democratic government imposed victors abdication Kaiser Wilhelm 11 Much map Europe redrawn victors based upon theory future wars could prevented ethnic groups homeland New states like Yugoslavia Czechoslovakia created former Austro Hungarian Empire accommodate nationalist aspirations groups 12 An international body called League Nations formed mediate disputes prevent future wars although effectiveness severely limited among things reluctance inability act 13 Russian Revolution communism Main article Russian RevolutionThe Russian Revolution 1917 ending overthrow Tsarist regime execution His Imperial Majesty Nicholas II family sparked wave communist revolutions across Europe prompting many believe socialist world revolution could realized near future 14 However European revolutions defeated Vladimir Lenin died 1924 within years Joseph Stalin displaced Leon Trotsky de facto leader Soviet Union idea worldwide revolution longer forefront Stalin concentrated socialism one country 15 embarked bold plan collectivization industrialization 16 majority socialists even many communists became disillusioned Stalin autocratic rule purges assassination enemies well news famines imposed people 17 Communism strengthened force Western democracies global economy crashed 1929 became known Great Depression Many people saw first stage end capitalist system attracted Communism solution economic crisis especially Soviet Union economic development 1930s strong unaffected capitalist world crisis 18 Between wars Dorothea Lange 1936 photo Migrant Mother one iconic photos associated Great Depressi ...

# %%
# Create a count for the countries
all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
# Checking counts list
print(all_counts)
# Out:
# Counter({'war': 79, 'War': 55, 'Soviet': 49, 'Hitler': 39, 'first': 36, 'World': 33, 'world': 32, 'Germany': 32, 'German': 31, 'Japanese': 31, 'Germans': 29, 'Union': 28, 'became': 28, 'also': 27, 'United': 26, 'Japan': 26, 'century': 23, 'Europe': 23, 'weapons': 23, 'nuclear': 23, 'new': 22, 'States': 21, 'U': 20, 'attack': 20, 'end': 19, 'Allies': 19, 'British': 19, 'many': 19, 'Allied': 18, 'could': 18, 'This': 18, 'countries': 17, 'Main': 17, 'two': 17, 'forces': 17, 'However': 17, 'one': 17, 'Jews': 17, 'later': 17, 'American': 16, 'II': 16, 'Stalin': 16, 'S': 16, 'led': 15, 'computer': 15, 'article': 14, 'July': 14, 'known': 14, 'France': 14, 'nations': 14, 'people': 14, '1945': 14, 'North': 14, 'South': 13, 'used': 13, 'began': 13, 'battle': 13, 'invasion': 13, 'Cold': 12, 'power': 12, 'troops': 12, 'came': 12, 'economic': 12, 'time': 12, 'made': 12, 'early': 12, 'Poland': 12, 'Berlin': 12, 'Africa': 12, 'On': 12, 'space': 11, 'major': 11, 'government': 11, 'New': 11, 'Britain': 11, 'use': 11, 'launched': 11, 'Army': 11, 'Battle': 11, 'After': 10, 'military': 10, '2': 10, 'Western': 10, 'army': 10, '1944': 10, 'several': 10, 'including': 9, 'Great': 9, 'next': 9, 'state': 9, 'August': 9, 'days': 9, 'East': 9, 'bomb': 9, '1942': 9, 'By': 9, 'West': 9, 'Pacific': 9, 'China': 9, 'island': 9, 'creation': 8, 'wars': 8, 'Empire': 8, 'states': 8, 'independence': 8, 'aircraft': 8, 'see': 8, 'forced': 8, 'communist': 8, 'force': 8, 'Italy': 8, 'Nazi': 8, 'Eastern': 8, 'history': 8, 'attacks': 8, 'air': 8, 'territory': 8, 'June': 8, 'million': 8, 'day': 8, 'city': 8, 'controlled': 8, 'naval': 8, 'influence': 8, 'Korea': 8, 'Vietnam': 8, '20th': 7, 'beginning': 7, '1': 7, 'Russia': 7, '6': 7, '7': 7, 'form': 7, 'set': 7, 'groups': 7, 'Nations': 7, 'among': 7, 'system': 7, 'crisis': 7, 'general': 7, 'Mussolini': 7, 'large': 7, 'took': 7, 'September': 7, 'part': 7, 'surrendered': 7, 'French': 7, 'independent': 7, 'almost': 7, 'turned': 7, 'launch': 7, 'largest': 7, 'despite': 7, 'A': 7, 'already': 7, 'offensive': 7, 'US': 7, 'V': 7, 'leading': 7, 'last': 7, 'second': 7, 'powers': 7, 'Chinese': 7, '000': 7, 'camps': 7, 'computers': 7, 'SSR': 7, 'Internet': 7, 'created': 6, 'powerful': 6, 'ended': 6, 'advance': 6, 'warfare': 6, 'occupied': 6, 'upon': 6, 'communism': 6, 'European': 6, 'country': 6, 'even': 6, 'well': 6, 'capitalist': 6, 'articles': 6, '20': 6, 'rise': 6, 'east': 6, 'He': 6, 'area': 6, 'held': 6, 'Holocaust': 6, '1941': 6, 'defeat': 6, 'massive': 6, 'important': 6, 'At': 6, 'Nazis': 6, 'Operation': 6, 'suffered': 6, 'turn': 6, 'bombing': 6, 'planned': 6, 'campaign': 6, 'network': 6, 'Rommel': 6, 'half': 6, 'place': 6, 'long': 6, 'another': 6, 'human': 6, 'surrender': 6, 'India': 6, 'nation': 6, 'systems': 6, 'decades': 6, 'software': 6, 'networks': 6, 'Space': 5, 'marked': 5, 'saw': 5, '1914': 5, '1918': 5, 'caused': 5, 'Russian': 5, 'since': 5, 'advances': 5, '9': 5, 'finally': 5, 'years': 5, 'Many': 5, '10': 5, 'like': 5, 'ending': 5, 'within': 5, 'Joseph': 5, 'idea': 5, 'plan': 5, 'rule': 5, 'global': 5, 'development': 5, 'strong': 5, 'political': 5, 'become': 5, 'They': 5, 'free': 5, 'soldiers': 5, 'population': 5, 'race': 5, 'put': 5, 'General': 5, 'control': 5, 'Pact': 5, 'Moscow': 5, 'Second': 5, 'USSR': 5, 'winter': 5, '1940': 5, 'May': 5, 'April': 5, 'With': 5, 'refused': 5, 'managed': 5, 'Italians': 5, 'taking': 5, 'weapon': 5, 'Despite': 5, 'divided': 5, 'Axis': 5, 'ground': 5, 'victories': 5, 'Churchill': 5, 'followed': 5, 'continued': 5, 'possible': 5, 'still': 5, 'cities': 5, 'killed': 5, 'home': 5, 'develop': 5, 'efforts': 5, 'developed': 5, 'formation': 5, 'PC': 5, 'changed': 4, 'atomic': 4, 'based': 4, 'Web': 4, 'These': 4, 'lives': 4, '21st': 4, 'events': 4, 'started': 4, 'period': 4, 'Central': 4, 'Austria': 4, 'Treaty': 4, 'although': 4, 'cost': 4, 'treaty': 4, '3': 4, 'especially': 4, 'boats': 4, 'sign': 4, 'back': 4, 'never': 4, 'future': 4, 'ethnic': 4, 'Yugoslavia': 4, 'Czechoslovakia': 4, 'forme ...

# %%
# Importing countries list csv
path = r'C:\Users\jboer\20th-Century\countries_list_20th_century_1.5.csv'
country = pd.read_csv(path, index_col = 0)

# %%
# Checking dataframe
country.head()
# Out:
#   country_name
# 1  Afghanistan
# 2      Albania
# 3      Algeria
# 4      Andorra
# 5       Angola

# %%
# Converting country dataframe to list
country_list = country['country_name'].to_list()

# %%
# Mapping variations of country names
country_var = {
    "United States": ['United States', 'US', 'USA', 'America', 'American', 'Americans', 'States', 'U'],
    "Germany": ['Germany', 'Germans', 'German'],
    "United Kingdom": ['United Kingdom', 'Britain', 'Kingdom', 'England', 'British'],
    "Australia": ['Australia', 'Australians'],
    "Japan": ['Japan', 'Japanese'],
    "China, People's Republic of": ['China', 'Chinese'],
    "Korea, North": [('North Korea'), ('North Korean'), ('North Koreans')],
    "Korea, South": [('South Korea'), ('South Korean'), ('South Koreans')],
    "France": ['France', 'French'],
    "Vietnam": ['Vietnam', 'Vietnamese'],
    "Russia": ['Russia', 'Russian', 'Russians', 'USSR', 'Soviet'],
    "Czech Republic": ['Czech Republic', 'Czechoslovakia', 'Czech'],
    "Hungary": ['Hungary', 'Hungarian', 'Hungarians'],
    "Finland": ['Finland', 'Finnish'],
    "Sweden": ['Sweden', 'Swedish']
}

# %%
# Initialize dictionary to store the counts for each country
country_counts = {country: 0 for country in country_list}

# Replace multi-word country names with placeholders
for country, variations in country_var.items():
    for variation in variations:
        if ' ' in variation:  # Check for multi-word country names
            placeholder = variation.replace(' ', '_')
            listToStr = re.sub(r'\b' + re.escape(variation) + r'\b', placeholder, listToStr)

# Tokenize the modified text
tokens = listToStr.split()
all_counts = Counter(tokens)

# Count the occurrences of each country variation
for word, count in all_counts.items():
    for country, variations in country_var.items():
        if word in variations:
            country_counts[country] += count
            break

# Adjust counts for multi-word country names
for country, variations in country_var.items():
    for variation in variations:
        if ' ' in variation:
            placeholder = variation.replace(' ', '_')
            if placeholder in all_counts:
                country_counts[country] += all_counts[placeholder]

# Display the counts for each country
for country, count in country_counts.items():
    print(f"{country}: {count}")
# Out:
# Afghanistan: 0
# Albania: 0
# Algeria: 0
# Andorra: 0
# Angola: 0
# Antigua and Barbuda: 0
# Argentina: 0
# Armenia: 0
# Australia: 2
# Austria: 0
# Azerbaijan: 0
# Bahamas, The: 0
# Bahrain: 0
# Bangladesh: 0
# Barbados: 0
# Belarus: 0
# Belgium: 0
# Belize: 0
# Benin: 0
# Bhutan: 0
# Bolivia: 0
# Bosnia and Herzegovina: 0
# Botswana: 0
# Brazil: 0
# Brunei: 0
# Bulgaria: 0
# Burkina Faso: 0
# Burundi: 0
# Cambodia: 0
# Cameroon: 0
# Canada: 0
# Cape Verde: 0
# Central African Republic: 0
# Chad: 0
# Chile: 0
# China, People's Republic of: 16
# Colombia: 0
# Comoros: 0
# Congo, Democratic Republic of the: 0
# Congo, Republic of the: 0
# Costa Rica: 0
# Croatia: 0
# Cuba: 0
# Cyprus: 0
# Czech Republic: 6
# Denmark: 0
# Djibouti: 0
# Dominica: 0
# Dominican Republic: 0
# East Timor: 0
# Ecuador: 0
# Egypt: 0
# El Salvador: 0
# Equatorial Guinea: 0
# Eritrea: 0
# Estonia: 0
# Eswatini: 0
# Ethiopia: 0
# Fiji: 0
# Finland: 4
# France: 21
# Gabon: 0
# Gambia, The: 0
# Georgia: 0
# Germany: 92
# Ghana: 0
# Greece: 0
# Grenada: 0
# Guatemala: 0
# Guinea: 0
# Bissau: 0
# Guyana: 0
# Haiti: 0
# Honduras: 0
# Hungary: 5
# Iceland: 0
# India: 0
# Indonesia: 0
# Iran: 0
# Iraq: 0
# Ireland: 0
# Israel: 0
# Italy: 0
# Ivory Coast: 0
# Jamaica: 0
# Japan: 57
# Jordan: 0
# Kazakhstan: 0
# Kenya: 0
# Kiribati: 0
# Korea, North: 5
# Korea, South: 2
# Kuwait: 0
# Kyrgyzstan: 0
# Laos: 0
# Latvia: 0
# Lebanon: 0
# Lesotho: 0
# Liberia: 0
# Libya: 0
# Liechtenstein: 0
# Lithuania: 0
# Luxembourg: 0
# Madagascar: 0
# Malawi: 0
# Malaysia: 0
# Maldives: 0
# Mali: 0
# Malta: 0
# Marshall Islands: 0
# Mauritania: 0
# Mauritius: 0
# Mexico: 0
# Micronesia, Federated States of: 0
# Moldova: 0
# Monaco: 0
# Mongolia: 0
# Montenegro: 0
# Morocco: 0
# Mozambique: 0
# Myanmar: 0
# Namibia: 0
# Nauru: 0
# Nepal: 0
# Netherlands: 0
# New Zealand: 0
# Nicaragua: 0
# Niger: 0
# Nigeria: 0
# North Macedonia: 0
# Norway: 0
# Oman: 0
# Pakistan: 0
# Palau: 0
# Palestine: 0
# Panama: 0
# Papua New Guinea: 0
# Paraguay: 0
# Peru: 0
# Philippines: 0
# Poland: 0
# Portugal: 0
# Qatar: 0
# Romania: 0
# Russia: 66
# Rwanda: 0
# Saint Kitts and Nevis: 0
# Saint Lucia: 0
# Saint Vincent and the Grenadines: 0
# Samoa: 0
# San Marino: 0
# São Tomé and Príncipe: 0
# Saudi Arabia: 0
# Senegal: 0
# Serbia: 0
# Seychelles: 0
# Sierra Leone: 0
# Singapore: 0
# Slovakia: 0
# Slovenia: 0
# Solomon Islands: 0
# Somalia: 0
# South Africa: 0
# South Sudan: 0
# Spain: 0
# Sri Lanka: 0
# Sudan: 0
# Suriname: 0
# Sweden: 2
# Switzerland: 0
# Syria: 0
# Tajikistan: 0
# Tanzania: 0
# Thailand: 0
# Togo: 0
# Tonga: 0
# Trinidad and Tobago: 0
# Tunisia: 0
# Turkey: 0
# Turkmenistan: 0
# Tuvalu: 0
# Uganda: 0
# Ukraine: 0
# United Arab Emirates: 0
# United Kingdom: 32
# United States: 70
# Uruguay: 0
# Uzbekistan: 0
# Vanuatu: 0
# Vatican City (Holy See): 0
# Venezuela: 0
# Vietnam: 11
# Yemen: 0
# Zambia: 0
# Zimbabwe: 0
# Abkhazia: 0
# Artsakh: 0
# Cook Islands: 0
# Donetsk People's Republic: 0
# Kosovo: 0
# Luhansk People's Republic: 0
# Niue: 0
# Northern Cyprus: 0
# Sahrawi Arab Democratic Republic: 0
# Somaliland: 0
# South Ossetia: 0
# Taiwan: 0
# Transnistria: 0

# %%
# Search for the names from the list in the dictionary
dct = {v:[k] for v,k in country_counts.items()}  
df = pd.DataFrame(dct)

# %%
# Checking dataframe
df
# Out:
#    Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# 0            0        0        0        0       0                    0
#
#    Argentina  Armenia  Australia  Austria  ...  Donetsk People's Republic  \
# 0          0        0          2        0  ...                          0
#
#    Kosovo  Luhansk People's Republic  Niue  Northern Cyprus  \
# 0       0                          0     0                0
#
#    Sahrawi Arab Democratic Republic  Somaliland  South Ossetia  Taiwan  \
# 0                                 0           0              0       0
#
#    Transnistria
# 0             0
#
# [1 rows x 208 columns]

# %%
# Transposing dataframe and resetting index
df = df.transpose().reset_index()

# %%
# Checking data types of dataframe
df.dtypes
# Out:
# index    object
# 0         int64
# dtype: object

# %%
# Re-checking dataframe
df.head()
# Out:
#          index  0
# 0  Afghanistan  0
# 1      Albania  0
# 2      Algeria  0
# 3      Andorra  0
# 4       Angola  0

# %%
# Renaming columns
df.rename(columns = {"index":"Country", 0:"Times mentioned"}, inplace = True)

# %%
# Checking results of columns name changes
df.head()
# Out:
#        Country  Times mentioned
# 0  Afghanistan                0
# 1      Albania                0
# 2      Algeria                0
# 3      Andorra                0
# 4       Angola                0

# %%
# Checking shape of dataframe
df.shape
# Out:
# (208, 2)

# %%
# Creating bar plot of top 15 most frequently mentioned countries

# Filtering dataframe to include only the top 15 countries
top_15_countries = df.sort_values("Times mentioned", ascending=False).head(15)

# Creating plot
plt.figure(figsize=(15, 8))
with sns.dark_palette("#79C", 27):
    sns.barplot(x = "Times mentioned", y = "Country",
    saturation=0.9, data = top_15_countries).set_title("20th Century Events - most frequently mentioned countries")

# Save figure
plt.savefig('most_frequent_countries.png')

plt.show()

# %% [markdown]
# #### In this plot (including the counts of all countries and their variations) we can see that Germany was mentioned the most followed by United States and Russia. Even knowing a bit of history about the 20th century, this makes sense since Germany and the United States were the biggest superpowers of that time. However, I would have expected the United States to be the country that was most mentioned. With this inforamtion we are able to get an understanding of which countries were most involved in the events of the 20th century.

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# #### My expectations of a sentiment analysis of this text is the polarity will be closer to a -1 meaning it will have a more negative sentiment since a lot of the events included war and conflict. I also believe the subjectivity will be close to 0 since these are factual, historical events rather than fiction.

# %%
# Conducting sentiment analysis
text_sent = TextBlob(str(tokenized_word_3))

# %%
# Showing results
print(text_sent.sentiment)
# Out:
# Sentiment(polarity=0.04206656483509329, subjectivity=0.3511612599716787)

# %% [markdown]
# #### The results of the sentiment analysis show that the polarity is 0.04 which is higher than I expected. This shows that it has a slightly positive tone and suggests a balanced perspective that reflects the challenges and achievements of the era. The slightly positive tone may account for a hopeful outlook of humanity regardless of the atrocities faced in the 20th century. The subjectivity is 0.35 which is closer to 0 (still higher than I thought it would be) so it does indicate that the text is more factual than fictitous, but may contain personal opinions or interpretations of the events. I also find it would be difficult to be completely objective when writing about some of the most horrible events in human history.
