# %% [markdown]
# # Name Entity Recognition(NER) Network Analysis

# %%
# Import libraries
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module of spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 2.4 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.3/12.8 MB 2.7 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.3/12.8 MB 2.7 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.3/12.8 MB 2.7 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.8/12.8 MB 1.5 MB/s eta 0:00:08
#      -------- ------------------------------- 2.6/12.8 MB 1.9 MB/s eta 0:00:06
#      ---------- ----------------------------- 3.4/12.8 MB 2.2 MB/s eta 0:00:05
#      ------------- -------------------------- 4.2/12.8 MB 2.4 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.2/12.8 MB 2.7 MB/s eta 0:00:03
#      -------------------- ------------------- 6.6/12.8 MB 3.0 MB/s eta 0:00:03
#      ------------------------- -------------- 8.1/12.8 MB 3.5 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.8 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.21)
# Requirement already satisfied: jinja2 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.5)
# Requirement already satisfied: setuptools in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (75.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\jboer\anaconda3\envs\venv_20th_century\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.2.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module
NER = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Load 20th Century Events Text

# %%
# Defining path
path = r'C:\Users\jboer\20th-Century\20th_Century_Wiki_cleaned.txt'
# Loading text
with open(path, 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %%
# Creating NER object
text = NER(data)

# %%
# Visualize identified entities
displacy.render(text[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">form defense advances sides slow came terrible cost lives
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Division Austria Hungary World War I
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  When war finally
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1918
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  results set stage
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     next twenty years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  foremost
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  forced sign
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Treaty Versailles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  forcing make exorbitant payments repair damages caused
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  Many
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  felt reparations unfair actually lose war feel caused war see Stab in the back legend
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  never occupied
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Allied
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  troops yet accept liberal democratic government imposed victors abdication
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kaiser Wilhelm Much
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  map
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  redrawn victors based upon theory future wars could prevented ethnic groups homeland New states like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yugoslavia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Czechoslovakia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  created former
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austro Hungarian Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  accommodate nationalist aspirations groups An international body called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     League Nations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  formed mediate disputes prevent future wars although effectiveness severely limited among things reluctance inability act
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Revolution communism Main article
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian Revolution The Russian Revolution 1917
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  ending overthrow
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tsarist
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  regime execution His
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Imperial
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Majesty
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nicholas II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  family sparked wave communist revolutions across
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  prompting many believe socialist world revolution could realized near future
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     However European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius:

# %% [markdown]
# ## Get sentence entities from NER object

# %%
df_sentences = [] # empty shell to store results

# Loop through sentences, get entity list for each sentence
for sent in text.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})
    
df_sentences = pd.DataFrame(df_sentences)

# %%
# Checking df_sentences dataframe
df_sentences.head()
# Out:
#                                             sentence  \
# 0  (20th, century, changed, world, unprecedented,...
# 1  (The, new, beginning, 20th, century, marked, s...
# 2  (Russia, ended, hostile, actions, Central, Pow...
# 3  (Division, Austria, Hungary, World, War, I, Wh...
# 4  (New, states, like, Yugoslavia, Czechoslovakia...
#
#                                             entities
# 0  [20th century, World Wars, Cold War led, 21st ...
# 1  [20th century, 1900s, decade, 1914, Panama Can...
# 2  [Russia, Central Powers, Tsar Bolsheviks, Trea...
# 3  [Division Austria Hungary World War I, 1918, n...
# 4  [Yugoslavia, Czechoslovakia, Austro Hungarian ...

# %% [markdown]
# ## Load country names

# %%
# Import country names
path = r'C:\Users\jboer\20th-Century\countries_list_20th_century_1.5.csv'
country = pd.read_csv(path, index_col = 0)

# %%
# Checking dataframe
print(country.head())
# Out:
#   country_name
# 1  Afghanistan
# 2      Albania
# 3      Algeria
# 4      Andorra
# 5       Angola

# %%
# Mapping variations of country names
country_var = {
    "United States": ['United States', 'US', 'USA', 'America', 'American', 'Americans', 'States', 'U'],
    "Germany": ['Germany', 'Germans', 'German'],
    "United Kingdom": ['United Kingdom', 'Britain', 'Kingdom', 'England', 'British'],
    "Australia": ['Australia', 'Australians'],
    "Japan": ['Japan', 'Japanese'],
    "China, People's Republic of": ['China', 'Chinese'],
    "Korea, North": [('North Korea'), ('North Korean'), ('North Koreans')],
    "Korea, South": [('South Korea'), ('South Korean'), ('South Koreans')],
    "France": ['France', 'French'],
    "Vietnam": ['Vietnam', 'Vietnamese'],
    "Russia": ['Russia', 'Russian', 'Russians', 'USSR', 'Soviet'],
    "Czech Republic": ['Czech Republic', 'Czechoslovakia', 'Czech'],
    "Hungary": ['Hungary', 'Hungarian', 'Hungarians'],
    "Finland": ['Finland', 'Finnish'],
    "Sweden": ['Sweden', 'Swedish']
}

# %% [markdown]
# #### By creating a map of all the variations a country could have in the text, I am ensuring that every mention of a country, whether by it's formal name or some other variation of it's name, will be counted. This will give me a more accurate representation of the number of times a country is mentioned.

# %%
# Creating dataframe for country variations
data = []
for country, variations in country_var.items():
    for variation in variations:
        data.append([country, variation])
        
df_var = pd.DataFrame(data, columns=['country_name', 'variation'])

# %%
df_var.head()
# Out:
#     country_name      variation
# 0  United States  United States
# 1  United States             US
# 2  United States            USA
# 3  United States        America
# 4  United States       American

# %%
# Merging country dataframe with df_var dataframe
df_merged = pd.merge(country, df_var, on='country_name', how='left')

# %%
print(df_merged)
# Out:
#                          country_name variation
# 0                         Afghanistan       NaN
# 1                             Albania       NaN
# 2                             Algeria       NaN
# 3                             Andorra       NaN
# 4                              Angola       NaN
# ..                                ...       ...
# 236  Sahrawi Arab Democratic Republic       NaN
# 237                        Somaliland       NaN
# 238                     South Ossetia       NaN
# 239                            Taiwan       NaN
# 240                      Transnistria       NaN
#
# [241 rows x 2 columns]

# %%
# Filling null values in variation column
df_merged['variation'] = df_merged['variation'].fillna(df_merged['country_name'])

# %%
print(df_merged)
# Out:
#                          country_name                         variation
# 0                         Afghanistan                       Afghanistan
# 1                             Albania                           Albania
# 2                             Algeria                           Algeria
# 3                             Andorra                           Andorra
# 4                              Angola                            Angola
# ..                                ...                               ...
# 236  Sahrawi Arab Democratic Republic  Sahrawi Arab Democratic Republic
# 237                        Somaliland                        Somaliland
# 238                     South Ossetia                     South Ossetia
# 239                            Taiwan                            Taiwan
# 240                      Transnistria                      Transnistria
#
# [241 rows x 2 columns]

# %% [markdown]
# ## Filtering entities from text

# %%
# Function to filter out entities not of interest
def filter_entity(ent_list, df_merged):
    return [ent for ent in ent_list 
            if ent in list(df_merged['variation'])]

# %%
# Check
filter_entity(["Germany", "CF", "2"], df_merged)
# Out:
# ['Germany']

# %%
# Creating list of entities
df_sentences['country_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, df_merged))

# %%
# Checking list
df_sentences['country_entities'].head(20)
# Out:
# 0                                                    []
# 1           [British, France, German, Austria, Hungary]
# 2     [Russia, Germany, Russia, Germany, Ukraine, Ge...
# 3                           [Germans, Germans, Germany]
# 4                                      [Czechoslovakia]
# 5                                             [Russian]
# 6                                                    []
# 7                                                    []
# 8                                                    []
# 9                                                    []
# 10    [Germans, Germany, Italy, Germany, Germany, Ge...
# 11    [German, German, Germans, United States, Germany]
# 12                        [German, Czech, Czech, Spain]
# 13                                                   []
# 14                                                   []
# 15                                                   []
# 16                                                   []
# 17    [Czechoslovakia, Britain, France, Poland, Pola...
# 18                                                   []
# 19                                                   []
# Name: country_entities, dtype: object

# %%
# Filter out sentences that don't have any country entities
df_sentences_filtered = df_sentences[df_sentences['country_entities'].map(len) > 0]

# %%
# Checking filtered sentences
df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 76   (Korean, War, Vietnam, War, Cuban, Missile, Cr...
# 78   (After, French, withdrawal, former, colony, 21...
# 79   (This, Nixon, Doctrine, involved, gradual, pul...
# 80   (Vietnam, unified, Communist, rule, year, late...
# 81   (Five, landings, astronauts, followed, Apollo,...
# 83   (By, 1980s, Soviet, Union, weakening, Sino, So...
# 84   (Its, arms, race, US, draining, country, funds...
# 96   (By, end, century, technological, advances, sc...
# 97   (This, led, anti, Western, anti, American, fee...
# 100  (Third, World, However, developing, countries,...
#
#                                               entities  \
# 76   [Korean War Vietnam War Cuban Missile Crisis, ...
# 78   [French, 21 July 1954, Vietnam, two, Korea, 17...
# 79   [Nixon, American, South Vietnamese, American, ...
# 80   [Vietnam, Communist, year later, one, Cuban Mi...
# 81   [Five, Apollo, 13, US, Soviet, early 21st cent...
# 83   [1980s Soviet Union, Sino Soviet, USSR, People...
# 84   [US, Mikhail Gorbachev, Solidarity, Berlin, So...
# 96   [end century, Europe, first, Indian, sixth, en...
# 97   [Western, American, Middle East, China, India,...
# 100  [South Africa, Nelson Mandela, first, four hal...
#
#                                       country_entities
# 76   [China, North Korea, United States, South Kore...
# 78   [French, Vietnam, United States, American, US,...
# 79          [American, American, Cambodia, US, US, US]
# 80   [Vietnam, United States, Cuba, Soviet, US, Sov...
# 81   [US, Soviet, United States, Russia, Japan, Can...
# 83                                              [USSR]
# 84                     [US, Soviet, Lithuania, Russia]
# 96                                         [China, US]
# 97                            [American, China, India]
# 100                [South Africa, Rwanda, North Korea]

# %% [markdown]
# ## Create relationships

# %%
# Defining relationships 

# window size = 5 : this defines how many sentences will be looked at simultaneously 
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    country_list = sum((df_sentences_filtered.loc[i: end_i].country_entities), [])
    
    # Remove duplicated countries that are next to each other
    country_unique = [country_list[i] for i in range(len(country_list)) 
                   if (i==0) or country_list[i] != country_list[i-1]]
    
    if len(country_unique) > 1:
        for idx, a in enumerate(country_unique[:-1]):
            b = country_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
# Creating a dataframe for relationships
relationship_df = pd.DataFrame(relationships)

# %%
# Checking relationships dataframe
relationship_df
# Out:
#             source       target
# 0          British       France
# 1           France       German
# 2           German      Austria
# 3          Austria      Hungary
# 4          Hungary       Russia
# ...            ...          ...
# 1758        Rwanda  North Korea
# 1759  South Africa       Rwanda
# 1760        Rwanda  North Korea
# 1761  South Africa       Rwanda
# 1762        Rwanda  North Korea
#
# [1763 rows x 2 columns]

# %%
# Flattening variation dictionary to create a mapping dictionary
# Flatten the dictionary to create a mapping dictionary
mapping_dict = {variation: country for country, variations in country_var.items() for variation in variations}
print(mapping_dict)
# Out:
# {'United States': 'United States', 'US': 'United States', 'USA': 'United States', 'America': 'United States', 'American': 'United States', 'Americans': 'United States', 'States': 'United States', 'U': 'United States', 'Germany': 'Germany', 'Germans': 'Germany', 'German': 'Germany', 'United Kingdom': 'United Kingdom', 'Britain': 'United Kingdom', 'Kingdom': 'United Kingdom', 'England': 'United Kingdom', 'British': 'United Kingdom', 'Australia': 'Australia', 'Australians': 'Australia', 'Japan': 'Japan', 'Japanese': 'Japan', 'China': "China, People's Republic of", 'Chinese': "China, People's Republic of", 'North Korea': 'Korea, North', 'North Korean': 'Korea, North', 'North Koreans': 'Korea, North', 'South Korea': 'Korea, South', 'South Korean': 'Korea, South', 'South Koreans': 'Korea, South', 'France': 'France', 'French': 'France', 'Vietnam': 'Vietnam', 'Vietnamese': 'Vietnam', 'Russia': 'Russia', 'Russian': 'Russia', 'Russians': 'Russia', 'USSR': 'Russia', 'Soviet': 'Russia', 'Czech Republic': 'Czech Republic', 'Czechoslovakia': 'Czech Republic', 'Czech': 'Czech Republic', 'Hungary': 'Hungary', 'Hungarian': 'Hungary', 'Hungarians': 'Hungary', 'Finland': 'Finland', 'Finnish': 'Finland', 'Sweden': 'Sweden', 'Swedish': 'Sweden'}

# %%
# Replacing variations in relationship_df with main country names using mapping dictionary
relationship_df['source'] = relationship_df['source'].replace(mapping_dict)
relationship_df['target'] = relationship_df['target'].replace(mapping_dict)

# %%
# Checking dataframe
print(relationship_df.head())
# Out:
#            source   target
# 0  United Kingdom   France
# 1          France  Germany
# 2         Germany  Austria
# 3         Austria  Hungary
# 4         Hungary   Russia

# %% [markdown]
# #### Since I used the varaiation map before to make sure I counted each mention of a country, I will use it again to replace the varaiations in the dataframe with the actual country name, so that when I summarize the interactions, each variation will be counted under the proper country name.

# %%
# Sort the cases with a->b and b->a
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head(5)
# Out:
#     source          target
# 0   France  United Kingdom
# 1   France         Germany
# 2  Austria         Germany
# 3  Austria         Hungary
# 4  Hungary          Russia

# %%
# Summarize the interactions
relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

# %%
# Checking the summary of interactions
relationship_df.head(10)
# Out:
#            source          target  value
# 0          France  United Kingdom     55
# 1          France         Germany     42
# 2         Austria         Germany      2
# 3         Austria         Hungary      2
# 4         Hungary          Russia      8
# 5         Germany          Russia     57
# 6         Germany         Ukraine      6
# 7         Germany   United States     82
# 8  United Kingdom   United States     27
# 9         Germany  United Kingdom     73

# %% [markdown]
# #### Now I have a dataframe that is showing the interactions of each country in the text referred to by their actual country name, but still accouting for every varaition a country name could have had in the text.
# #### This dataframe will be useful to see how countries interact with each other in the text, ultimately telling us how closely related two countries are in the events of the 20th century.

# %%
# Export dataframe
relationship_df.to_csv('country_relationship.csv')
